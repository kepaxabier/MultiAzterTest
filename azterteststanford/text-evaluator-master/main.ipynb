# %% [markdown]
# Stanford CoreNLP – Natural language software
# With a single option you can change which tools should be enabled and disabled. Stanford CoreNLP integrates many of Stanford’s NLP tools, including the part-of-speech (POS) tagger, the named entity recognizer (NER), the parser, the coreference resolution system, sentiment analysis, bootstrapped pattern learning, and the open information extraction tools. Moreover, an annotator pipeline can include additional custom or third-party annotators. CoreNLP’s analyses provide the foundational building blocks for higher-level and domain-specific text understanding applications.
# Cite:
# @inproceedings{qi2018universal,
#  address = {Brussels, Belgium},
#  author = {Qi, Peng  and  Dozat, Timothy  and  Zhang, Yuhao  and  Manning, Christopher D.},
#  booktitle = {Proceedings of the {CoNLL} 2018 Shared Task: Multilingual Parsing from Raw Text to Universal Dependencies},
#  month = {October},
#  pages = {160--170},
#  publisher = {Association for Computational Linguistics},
#  title = {Universal Dependency Parsing from Scratch},
#  url = {https://nlp.stanford.edu/pubs/qi2018universal.pdf},
#  year = {2018}
# }
#
# Analizador Sintáctico: StanfordNLP
# https://stanfordnlp.github.io/stanfordnlp/
# pip install stanfordnlp
# To see StanfordNLP’s neural pipeline in action, you can launch the Python interactive interpreter, and try the following commands:
# https://stanfordnlp.github.io/stanfordnlp/

# %%
#Fileloader 
from file_loader import FileLoader
from printer import Printer
import nltk
####Argumentos##################################
from argparse import ArgumentParser
####analizador sintactico#######################
import stanfordnlp
import os

def start():
    from analyzer import Analyzer
    p = ArgumentParser(description="python3 ./main.py -f \"laginak/*.doc.txt\" ")
    optional = p._action_groups.pop()  # Edited this line
    required = p.add_argument_group('Required arguments')
    required.add_argument("-f", "--files", nargs='+', help="Files to analyze (in .txt, .odt, .doc or .docx format)")
    optional.add_argument('-a', '--all', action='store_true', help="Generate a CSV file with all the results")
    optional.add_argument('-s', '--similarity', action='store_true', help="Calculate similarity (max. 5 files)")
    p._action_groups.append(optional)
    opts = p.parse_args()
    FileLoader.load_files(opts.files)
    FileLoader.load_irregular_verbs_list()
    FileLoader.load_dale_chall_list()
    FileLoader.load_connectives_list()
    FileLoader.load_oxford_word_list()
    #Cargar el analizador
    stanfordnlp.download('en')
    stanford = stanfordnlp.Pipeline() 
    df_row = None
    ### Files will be created in this folder
    path = Printer.create_directory(FileLoader.files[0])
    file_num = 0
    total = len(FileLoader.files)
    for input in FileLoader.files:
        texto = Analyzer.process_text(input=input)
        # Analizar
        a = Analyzer(texto, input, stanford)
        i = a.analyze(opts.similarity)
        df = a.create_dataframe()
        prediction = a.predict_dificulty(df)
        file_num += 1
        p = Printer(input, i)
        p.print_info(opts.similarity, prediction, file_num, total)
        if opts.all:
            df_row = p.write_in_full_csv(df_row, opts.similarity)
        p.generate_csv(path, prediction, opts.similarity)
    if opts.all:
        df_row.to_csv(os.path.join(path, "full_results_aztertest.csv"), encoding='utf-8', index=False)

nltk.download('cmudict')
nltk.download('punkt')  # ,download_dir='/home/lsi/metrix-env/nltk_data')
nltk.download('stopwords')
nltk.download('wordnet')
start()
# Out:
# [nltk_data] Downloading package cmudict to /home/kepa/nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# [nltk_data] Downloading package punkt to /home/kepa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/kepa/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/kepa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# WARNING: Logging before flag parsing goes to stderr.
# W0905 15:25:39.924680 140648153802560 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Parametros: ['/run/user/1000/jupyter/kernel-b24e9775-3f77-4d5d-b548-b96d13c9d53a.json']
# Using the default treebank "en_ewt" for language "en".
# Would you like to download the models for: en_ewt now? (Y/n)
# Y
#
# Default download directory: /home/kepa/stanfordnlp_resources
# Hit enter to continue or type an alternate directory.
#
#
# Downloading models for: en_ewt
# Download location: /home/kepa/stanfordnlp_resources/en_ewt_models.zip
# 100%|██████████| 235M/235M [00:32<00:00, 6.64MB/s]
# Download complete.  Models saved to: /home/kepa/stanfordnlp_resources/en_ewt_models.zip
# Extracting models file for: en_ewt
# Cleaning up...Done.
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/textclassification/standfordparser/analyzer.py:358: RuntimeWarning: divide by zero encountered in double_scalars
#   self.indicators['honore'] = round(100 * ((np.log10(n)) / (1 - (v1 / v))), 4)
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-59e3e53a985e> in <module>
#      54 nltk.download('stopwords')
#      55 nltk.download('wordnet')
# ---> 56 start()
#
# <ipython-input-6-59e3e53a985e> in start()
#      40         i = a.analyze(opts.similarity)
#      41         df = a.create_dataframe()
# ---> 42         prediction = a.predict_dificulty(df)
#      43         file_num += 1
#      44         p = Printer(input, i)
#
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/textclassification/standfordparser/analyzer.py in predict_dificulty(self, data)
#    1139             selector = pickle.load(f)
#    1140
# -> 1141         X_test_new = selector.transform(X_test)
#    1142         return clf.predict(X_test_new)
#    1143
#
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/lib/python3.6/site-packages/sklearn/feature_selection/base.py in transform(self, X)
#      72             The input samples with only the selected features.
#      73         """
# ---> 74         X = check_array(X, dtype=None, accept_sparse='csr')
#      75         mask = self.get_support()
#      76         if not mask.any():
#
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# /media/datos/Dropbox/ikerkuntza/UZ/programak/jupyter/jupyter_env/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#      59         if _object_dtype_isnan(X).any():
# ---> 60             raise ValueError("Input contains NaN")
#      61
#      62
#
# ValueError: Input contains NaN

# %%
import stanfordnlp
#import nltk
#import sys
import re
####Numpy
import numpy as np
####input file##################
input="bostparrafo.txt"#sys.argv[1]
####ouput files#################
#estadisticos
estadisticaoutput=input+".out.csv"
#Write all the information in the file
estfile = open(estadisticaoutput, "w")
def sent2sequence(sent):
    #input:sent.words
    #[<Word index=1;text=;lemma=;>,
    #  <Word index=2;text=;lemma=;>,
    #]
    sequence=[]
    for word in sent.words:
       conllword=str(word.index)+"\t"+word.text+"\t"+word.lemma+"\t"+word.upos+"\t"+word.xpos+"\t"+word.feats+"\t"+str(word.governor)+"\t"+str(word.dependency_relation)
       sequence.append(conllword)
    #output:sequence:
    #[1 The the DET DT Feats 3 det _ _,
    #   2 Muslim .......................,
    #   3 .... ]
    return sequence

    
def is_verb(word_upos, word_governor, frase):
        #count = 0
        #while count < 3:
            #print(frase[count]) #1	The	the	DET	DT	Definite=Def|PronType=Art	3	det
            #values = frase[count].split("\t")
            #print(values[3])
            #count += 1  
        values = frase[int(word_governor) - 1].split("\t")
        if word_upos == 'VERB' or (word_upos == 'AUX' and values[3] != 'VERB'):
            #print (word.upos+"-"+values[3])
            return 1
        else:
            return 0


###############Tratamiento de texto###############################################
def process_text(input=None, text=None):
        # quitar todos los retornos \n si contiene
        if input is not None:
            if ".txt" not in input:
                pre_text = textract.process(input)
                text = pre_text.decode()
                text = text.replace('\n', '@')
            else:
                with open(input, encoding='utf-8') as f:
                    text = f.read().replace('\n', '@')
            text = re.sub(r'@+', '', text)
        # remove text inside parentheses
        # text = re.sub(r'\([^)]*\)', '', text)
        # separa , . ! ( ) ? ; del texto con espacios, teniendo en cuenta que los no son numeros en el caso de , y .
        text = re.sub(r'[.]+(?![0-9])', r' . ', text)
        text = re.sub(r'[,]+(?![0-9])', r' , ', text)
        text = re.sub(r"!", " ! ", text)
        text = re.sub(r"\(", " ( ", text)
        text = re.sub(r"\)", " ) ", text)
        text = re.sub(r"\?", " ? ", text)
        text = re.sub(r";", " ; ", text)
        # sustituye 2 espacios seguidos por 1
        text = re.sub(r"\s{2,}", " ", text)
        return text
#quitar todos los retornos \n si contiene
#text = open(input).read().replace('\n', '')
#remove text inside parentheses
#text = re.sub(r'\([^)]*\)', '', text)
#separa , . ! ( ) ? ; del texto con espacios, teniendo en cuenta que los no son numeros en el caso de , y . 
#text = re.sub(r'[.]+(?![0-9])', r' . ', text)
#text = re.sub(r'[,]+(?![0-9])', r' , ', text)
#text = re.sub(r"!", " ! ", text)
#text = re.sub(r"\(", " ( ", text)
#text = re.sub(r"\)", " ) ", text)
#text = re.sub(r"\?", " ? ", text)
#text = re.sub(r";", " ; ", text)
#sustituye 2 espacios seguidos por 1
#text = re.sub(r"\s{2,}", " ", text)
#stanfordnlp.download('en')   # This downloads the English models for the neural pipeline

standford = stanfordnlp.Pipeline() # This sets up a default neural pipeline in English
with open(input, encoding='utf-8') as f:
        text = f.read().replace('\n', '@')
#Si varios enters consecutivos en uno
text = re.sub(r'@+', '@', text)
#lines es una lista de parrafos
lines = text.split('@')
paragraphs = []
for line in lines:
        #si no es una linea vacia, añade en parrafos
        if not line.strip() == '':
            #Lista de texto formado por parrafos
            paragraphs.append(line)
            
from collections import defaultdict            
aux_lists = defaultdict(list)
aux_lists['paragraphs_list']=[]


for paragraph in paragraphs:
     #Parrafo a objeto doc Document object
     doc = standford(process_text(text=paragraph))
     ##doc.sentences es una lista de objectos sentence [doc.sentence1, doc.sentence2, ...]
     #hay que conseguir:[[sent1],[sent2],...[sentN]]
     sentences=[]
     for sent in doc.sentences:
        #sent2sequence output:[1 The the DET DT Feats 3 det _ _,2 Muslim ......,3 .... ]
        sentence=[]
        sentence=sent2sequence(sent)
        sentences.append(sentence)
     aux_lists['paragraphs_list'].append(sentences) #[[[sent1]]] o [[[sent1], [sent2]]]
     print(len(sentences))
        
#El texto se recorre por parrafos
adjacent_noun_overlap_list = []    
#El texto se recorre por parrafos
for paragraph in aux_lists['paragraphs_list']:
      #Por cada parrafo:paragraph es "lista de obj sentencias" de un parrafo=[doc.sentence1,...]
      if len(paragraph) > 1:
                #print(paragraph) #[[[sent1]]] o [[[sent1], [sent2]]]
                #print("paragraph[1:]:")
                #print(paragraph[1:]) # se extrae una lista de sentencias de parrafo a partir del índice 1(incluido)
                #zip Python zip function takes iterable elements as input, and returns iterator que es un flujo de datos que 
                #puede ser recorrido por for o map.
                #Si paragraph = [[sentence1], [sentence2], [sentence3]]
                #paragraph[1:] = [[sentence2], [sentence3]]
                test = zip(paragraph, paragraph[1:])  # zip the values
                #print(test) #-><zip object at 0x7eff7b354c08>=?[([sentence1],[sentence2]),([sentence2],[sentence3]),...]
                #for values in test:
                    #print(values)  # print each tuples
                    #([sentence1],[sentence2])
                    #([sentence2],[sentence3])
                #map aplica la función list a todos los elementos de zip y como resultado se devuelve un iterable de tipo map
                #funcion list=The list() constructor returns a mutable (the object can be modified) sequence list of elements.
                # Por cada valor de test genera una lista
                testlist=map(list, test)
                #print(testlist) #<map object at 0x7eff7b3701d0>=?[[([sentence1],[sentence2])],[([sentence2],[sentence3])]]
                adjacents = list(map(list, test))
                #print(type(adjacents))
                print(adjacents) ##Ejm: Parrafo1:[[[sent1], [sent2]], [[sent2], [sent3]]] donde sentenceX es conllword1,conllword2,... 
                for x in adjacents:
                   #x es [[sentence1], [sentence2]]
                   sentence1 = []
                   sentence2 = []
                   for entry1 in x[0]:
                   # x[0] sera [sentence1] o [conllword1,conllword2,...]
                        values1=entry1.split("\t")
                        if values1[3] == 'NOUN':
                           sentence1.append(values1[1].lower())
                   for entry2 in x[1]:
                        values2=entry2.split("\t")
                        if values2[3] == 'NOUN':
                           sentence2.append(values2[1].lower())
                   #nombres en comun entre sentence1 y sentence2
                   in_common = list(set(sentence1).intersection(sentence2))
                   #si hay nombre en comun añado 1
                   if len(in_common) > 0:
                        adjacent_noun_overlap_list.append(1)
                   else:
                        adjacent_noun_overlap_list.append(0)

if len(adjacent_noun_overlap_list) > 0:
            aux_lists['noun_overlap_adjacent'] = round(float(np.mean(adjacent_noun_overlap_list)), 4)
print(aux_lists['noun_overlap_adjacent'])

#def calculate_noun_overlap_all(self):
#?i = self.indicators
all_noun_overlap_list = []
for paragraph in aux_lists['paragraphs_list']:
       for index in range(len(paragraph)):
            similarity_tmp = paragraph[index + 1:]
            x = paragraph[index]
            for index2 in range(len(similarity_tmp)):
                y = similarity_tmp[index2]
                sentence1 = []
                sentence2 = []
                for entry1 in x:
                    values1=entry1.split("\t")
                    if values1[3] == 'NOUN':
                        sentence1.append(values1[1].lower())
                for entry2 in y:
                    values2=entry2.split("\t")
                    if values2[3] == 'NOUN':
                        sentence2.append(values2[1].lower())    
                in_common = list(set(sentence1).intersection(sentence2))
                if len(in_common) > 0:
                        all_noun_overlap_list.append(1)
                else:
                        all_noun_overlap_list.append(0)
if len(all_noun_overlap_list) > 0:
      print(round(float(np.mean(all_noun_overlap_list)), 4))
#def calculate_argument_overlap_adjacent(self):
#i = self.indicators
def is_personal_pronoun(word):
    values=word.split("\t")
    atributos = values[5].split('|')
    return "PronType=Prs" in atributos
    
adjacent_argument_overlap_list = []
for paragraph in aux_lists['paragraphs_list']:
     if len(paragraph) > 1:
        adjacents = list(map(list, zip(paragraph, paragraph[1:])))
        for x in adjacents:
            sentence1 = []
            sentence2 = []
            for entry1 in x[0]:
                values1=entry1.split("\t")
                if is_personal_pronoun(entry1) or values1[3] == 'NOUN':
                           sentence1.append(values1[2].lower())
            for entry2 in x[1]:
                values2=entry2.split("\t")
                if is_personal_pronoun(entry2) or values2[3] == 'NOUN':
                           sentence2.append(values2[2].lower())
            in_common = list(set(sentence1).intersection(sentence2))
            if len(in_common) > 0:
                    adjacent_argument_overlap_list.append(1)
            else:
                    adjacent_argument_overlap_list.append(0)
if len(adjacent_argument_overlap_list) > 0:
      print(round(float(np.mean(adjacent_argument_overlap_list)), 4))


def is_lexic_word(word_upos, word_governor, sequence):
        return is_verb(word_upos, word_governor, sequence) or word_upos == 'NOUN' or word_upos == 'ADJ' or word_upos == 'ADV'

#def calculate_stem_overlap_adjacent(self):
adjacent_stem_overlap_list = []
for paragraph in aux_lists['paragraphs_list']:
    if len(paragraph) > 1:
        adjacents = list(map(list, zip(paragraph, paragraph[1:])))
        for x in adjacents:
            sentence1 = []
            sentence2 = []
            for entry1 in x[0]:
                values1=entry1.split("\t")
                #sequence=[1 The the DET DT Feats 3 det _ _,2 Muslim ......,3 .... ]
                #x[0]=['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,
                print("x[0]:")
                print(x[0])
                if is_lexic_word(values1[3],values1[6], x[0]):
                    sentence1.append(values1[2].lower())
            for entry2 in x[1]:
                values2=entry2.split("\t")
                if values2[3] == 'NOUN':
                    sentence2.append(values2[2].lower())
            in_common = list(set(sentence1).intersection(sentence2))
            if len(in_common) > 0:
                  adjacent_stem_overlap_list.append(1)
            else:
                  adjacent_stem_overlap_list.append(0)
if len(adjacent_stem_overlap_list) > 0:
            print(round(float(np.mean(adjacent_stem_overlap_list)), 4))
#def calculate_stem_overlap_all(self):
#        i = self.indicators
all_stem_overlap_list = []
for paragraph in aux_lists['paragraphs_list']:
    for index in range(len(paragraph)):
        similarity_tmp = paragraph[index + 1:]
        x = paragraph[index]
        for index2 in range(len(similarity_tmp)):
            y = similarity_tmp[index2]
            sentence1 = []
            sentence2 = []
            for entry1 in x:
                values1=entry1.split("\t")
                if is_lexic_word(values1[3],values1[6], x):
                    sentence1.append(values1[2].lower())
            for entry2 in y:
                values2=entry2.split("\t")
                if values2[3] == 'NOUN':
                    sentence2.append(values2[2].lower())
            in_common = list(set(sentence1).intersection(sentence2))
            if len(in_common) > 0:
               all_stem_overlap_list.append(1)
            else:
               all_stem_overlap_list.append(0)
if len(all_stem_overlap_list) > 0:
        print(round(float(np.mean(all_stem_overlap_list)), 4))
#def calculate_content_overlap_adjacent(self):
#i = self.indicators
def count_content_words_in(sent):
        num_words = 0
        for entry in sent:
            values=entry.split("\t")
            if is_verb(values[3],values[6], sent) or values[3] == 'NOUN' or values[3] == 'ADJ' or values[3] == 'ADV':
                num_words += 1
        return num_words



adjacent_content_overlap_list = []
for paragraph in aux_lists['paragraphs_list']:
     if len(paragraph) > 1:
                adjacents = list(map(list, zip(paragraph, paragraph[1:])))
                for x in adjacents:
                    sentence1 = []
                    sentence2 = []
                    for entry1 in x[0]:
                        values1=entry1.split("\t")
                        if is_lexic_word(values1[3],values1[6], x[0]):
                            sentence1.append(values1[1].lower())
                    for entry2 in x[1]:
                        values2=entry2.split("\t")
                        if is_lexic_word(values2[3],values2[6], x[1]):
                            sentence2.append(values2[1].lower())
                    in_common = list(set(sentence1).intersection(sentence2))
                    print("x[0]:\n")
                    print(x[0])
                    n1 = count_content_words_in(x[0])
                    n2 = count_content_words_in(x[1])
                    if n1 + n2 > 0:
                        adjacent_content_overlap_list.append(len(in_common) / (n1 + n2))
                    else:
                        adjacent_content_overlap_list.append(0)
if len(adjacent_content_overlap_list) > 0:
            print(round(float(np.mean(adjacent_content_overlap_list)), 4))
            print(round(float(np.std(adjacent_content_overlap_list)), 4))
#Todo el texto se recorre por sentencias
def calculate_left_embeddedness(doc):
#doc.sentences es una lista de objectos sentence [doc.sentence1, doc.sentence2, ...]
        list_left_embeddedness = []
        for sent in doc.sentences:
            verb_index = 0
            main_verb_found = False
            left_embeddedness = 0
            num_words = 0
            sequence=[]
            #sent2sequence output:[1 The the DET DT Feats 3 det _ _,2 Muslim ......,3 .... ]
            sequence=sent2sequence(sent)
            for word in sent.words:
                if not len(word.text) == 1 or word.text.isalpha():
                    if not main_verb_found and word.governor < len(sequence):
                        if is_verb(word.upos, word.governor, sequence):
                            verb_index += 1
                            wordgovernorvalues=sequence[word.governor-1].split("\t")
                            if (word.upos == 'VERB' and word.dependency_relation == 'root') or (word.upos == 'AUX' and wordgovernorvalues[7] == 'root' and wordgovernorvalues[3] == 'VERB'):
                                main_verb_found = True
                                left_embeddedness = num_words
                            if verb_index == 1:
                                left_embeddedness = num_words
                    num_words += 1
            list_left_embeddedness.append(left_embeddedness)
        print(round(float(np.mean(list_left_embeddedness)), 4))
doc = standford(text)
calculate_left_embeddedness(doc)
#print(len(doc.sentences))
#verb_index=0
#doc.sentences es una lista de objectos sentence [doc.sentence1, doc.sentence2, ...]
#for sent in doc.sentences:
#    sequence=[]
#    for entry in sent.words:
#        #sent.words=list of words of a sentence[<Word index=1;text=...;lemma=...;>,<Word index=2;..................;>,...]
#        sequence=sent2sequence(sent)
#        print(str(entry.index)+"\t"+entry.text+"\t"+entry.lemma+"\t"+entry.upos+"\t"+entry.xpos+"\t"+entry.feats+"\t"+str(entry.governor)+"\t"+str(entry.dependency_relation))
#        #if is_verb2(entry, sequence):
#           #verb_index += 1
#        if is_verb(entry, sent):
#            verb_index += 1
#print(verb_index) #22
estfile.close()
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/home/kepa/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# 1
# 3
# 2
# 3
# 3
# [[['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct'], ['1\tTheir\tthey\tPRON\tPRP$\tNumber=Plur|Person=3|Poss=Yes|PronType=Prs\t2\tnmod:poss', '2\tintention\tintention\tNOUN\tNN\tNumber=Sing\t3\tnsubj', '3\twas\tbe\tVERB\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t0\troot', '4\tto\tto\tPART\tTO\t_\t5\tmark', '5\tloot\tloot\tVERB\tVB\tVerbForm=Inf\t3\tccomp', '6\tand\tand\tCCONJ\tCC\t_\t7\tcc', '7\tplunder\tplunder\tVERB\tVB\tVerbForm=Inf\t5\tconj', '8\t.\t.\tPUNCT\t.\t_\t3\tpunct']], [['1\tTheir\tthey\tPRON\tPRP$\tNumber=Plur|Person=3|Poss=Yes|PronType=Prs\t2\tnmod:poss', '2\tintention\tintention\tNOUN\tNN\tNumber=Sing\t3\tnsubj', '3\twas\tbe\tVERB\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t0\troot', '4\tto\tto\tPART\tTO\t_\t5\tmark', '5\tloot\tloot\tVERB\tVB\tVerbForm=Inf\t3\tccomp', '6\tand\tand\tCCONJ\tCC\t_\t7\tcc', '7\tplunder\tplunder\tVERB\tVB\tVerbForm=Inf\t5\tconj', '8\t.\t.\tPUNCT\t.\t_\t3\tpunct'], ['1\tHaving\thave\tAUX\tVBG\tVerbForm=Ger\t3\taux', '2\teasily\teasily\tADV\tRB\t_\t3\tadvmod', '3\tdefeated\tdefeat\tVERB\tVBN\tTense=Past|VerbForm=Part\t19\tadvcl', '4\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t7\tdet', '5\tVisigoth\tVisigoth\tPROPN\tNNP\tNumber=Sing\t7\tcompound', '6\tKing\tKing\tPROPN\tNNP\tNumber=Sing\t7\tcompound', '7\tRodrigo\tRodrigo\tPROPN\tNNP\tNumber=Sing\t3\tobj', '8\tat\tat\tADP\tIN\t_\t10\tcase', '9\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t10\tdet', '10\tBattle\tBattle\tPROPN\tNNP\tNumber=Sing\t3\tobl', '11\tof\tof\tADP\tIN\t_\t12\tcase', '12\tGuadalete\tguadalete\tPROPN\tNNP\tNumber=Sing\t10\tnmod', '13\t(\t(\tPUNCT\t-LRB-\t_\t14\tpunct', '14\t711\t711\tNUM\tCD\tNumType=Card\t10\tappos', '15\t)\t)\tPUNCT\t-RRB-\t_\t14\tpunct', '16\t,\t,\tPUNCT\t,\t_\t19\tpunct', '17\tthey\tthey\tPRON\tPRP\tCase=Nom|Number=Plur|Person=3|PronType=Prs\t19\tnsubj:pass', '18\twere\tbe\tAUX\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t19\taux:pass', '19\tencouraged\tencourage\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '20\tto\tto\tPART\tTO\t_\t21\tmark', '21\tcontinue\tcontinue\tVERB\tVB\tVerbForm=Inf\t19\txcomp', '22\ttheir\tthey\tPRON\tPRP$\tNumber=Plur|Person=3|Poss=Yes|PronType=Prs\t23\tnmod:poss', '23\tadvance\tadvance\tNOUN\tNN\tNumber=Sing\t21\tobj', '24\t.\t.\tPUNCT\t.\t_\t19\tpunct']]]
# [[['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tPeninsula\tPeninsula\tPROPN\tNNP\tNumber=Sing\t3\tnsubj', '3\toffered\toffer\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '4\tlittle\tlittle\tADJ\tJJ\tDegree=Pos\t5\tamod', '5\tresistance\tresistance\tNOUN\tNN\tNumber=Sing\t3\tobj', '6\tand\tand\tCCONJ\tCC\t_\t9\tcc', '7\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t9\taux:pass', '8\tquickly\tquickly\tADV\tRB\t_\t9\tadvmod', '9\toccupied\toccupy\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t3\tconj', '10\t.\t.\tPUNCT\t.\t_\t3\tpunct'], ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tcauses\tcause\tNOUN\tNNS\tNumber=Plur\t6\tnsubj', '3\twere\tbe\tAUX\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t6\tcop', '4\tMuslim\tmuslim\tADJ\tJJ\tDegree=Pos\t6\tamod', '5\tmilitary\tmilitary\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tsuperiority\tsuperiority\tNOUN\tNN\tNumber=Sing\t0\troot', '7\t,\t,\tPUNCT\t,\t_\t10\tpunct', '8\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t10\tdet', '9\tinternal\tinternal\tADJ\tJJ\tDegree=Pos\t10\tamod', '10\tconflicts\tconflict\tNOUN\tNNS\tNumber=Plur\t6\tconj', '11\tof\tof\tADP\tIN\t_\t13\tcase', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tVisigoths\tvisigoth\tPROPN\tNNPS\tNumber=Plur\t10\tnmod', '14\t,\t,\tPUNCT\t,\t_\t18\tpunct', '15\tand\tand\tCCONJ\tCC\t_\t18\tcc', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t17\tdet', '17\tsupport\tsupport\tNOUN\tNN\tNumber=Sing\t18\tnsubj', '18\toffered\toffer\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t6\tconj', '19\tto\tto\tADP\tIN\t_\t21\tcase', '20\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t21\tdet', '21\tinvaders\tinvader\tNOUN\tNNS\tNumber=Plur\t18\tobl', '22\tby\tby\tADP\tIN\t_\t23\tcase', '23\tJews\tJews\tPROPN\tNNPS\tNumber=Plur\t21\tnmod', '24\tand\tand\tCCONJ\tCC\t_\t26\tcc', '25\tVisigoth\tVisigoth\tPROPN\tNNP\tNumber=Sing\t26\tcompound', '26\tnobles\tnoble\tNOUN\tNNS\tNumber=Plur\t23\tconj', '27\t,\t,\tPUNCT\t,\t_\t21\tpunct', '28\twho\twho\tPRON\tWP\tPronType=Rel\t29\tnsubj', '29\tsurrendered\tsurrender\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t21\tacl:relcl', '30\tin\tin\tADP\tIN\t_\t31\tcase', '31\texchange\texchange\tNOUN\tNN\tNumber=Sing\t29\tobl', '32\tfor\tfor\tSCONJ\tIN\t_\t33\tmark', '33\tkeeping\tkeep\tVERB\tVBG\tVerbForm=Ger\t31\tacl', '34\ttheir\tthey\tPRON\tPRP$\tNumber=Plur|Person=3|Poss=Yes|PronType=Prs\t35\tnmod:poss', '35\tproperties\tproperty\tNOUN\tNNS\tNumber=Plur\t33\tobj', '36\t.\t.\tPUNCT\t.\t_\t6\tpunct']]]
# [[['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t3\tdet', '2\tMuslim\tmuslim\tADJ\tJJ\tDegree=Pos\t3\tamod', '3\tinvasion\tinvasion\tNOUN\tNN\tNumber=Sing\t5\tnsubj:pass', '4\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t5\taux:pass', '5\thalted\thalt\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '6\tin\tin\tADP\tIN\t_\t10\tcase', '7\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t10\tdet', '8\tnorthern\tnorthern\tADJ\tJJ\tDegree=Pos\t10\tamod', '9\tmountainous\tmountainous\tADJ\tJJ\tDegree=Pos\t10\tamod', '10\tregion\tregion\tNOUN\tNN\tNumber=Sing\t5\tobl', '11\t,\t,\tPUNCT\t,\t_\t10\tpunct', '12\twhere\twhere\tADV\tWRB\tPronType=Rel\t18\tadvmod', '13\tcertain\tcertain\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tgroups\tgroup\tNOUN\tNNS\tNumber=Plur\t18\tnsubj', '15\tof\tof\tADP\tIN\t_\t17\tcase', '16\tChristian\tChristian\tPROPN\tNNP\tNumber=Sing\t17\tcompound', '17\tresistaoce\tresistaoce\tNOUN\tNNS\tNumber=Plur\t14\tnmod', '18\temerged\temerge\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t10\tacl:relcl', '19\t,\t,\tPUNCT\t,\t_\t24\tpunct', '20\tand\tand\tCCONJ\tCC\t_\t24\tcc', '21\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t22\tdet', '22\tMuslims\tMuslims\tPROPN\tNNPS\tNumber=Plur\t24\tnsubj:pass', '23\twere\tbe\tAUX\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t24\taux:pass', '24\tdefeated\tdefeat\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t5\tconj', '25\tby\tby\tADP\tIN\t_\t27\tcase', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t27\tdet', '27\tAsturians\tAsturians\tPROPN\tNNPS\tNumber=Plur\t24\tobl', '28\tin\tin\tADP\tIN\t_\t30\tcase', '29\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t30\tdet', '30\tBattle\tBattle\tPROPN\tNNP\tNumber=Sing\t24\tobl', '31\tof\tof\tADP\tIN\t_\t32\tcase', '32\tCovadonga\tCovadonga\tPROPN\tNNP\tNumber=Sing\t30\tnmod', '33\t(\t(\tPUNCT\t-LRB-\t_\t34\tpunct', '34\t722\t722\tNUM\tCD\tNumType=Card\t30\tappos', '35\t)\t)\tPUNCT\t-RRB-\t_\t34\tpunct', '36\t.\t.\tPUNCT\t.\t_\t5\tpunct'], ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tMusiims\tMusiims\tPROPN\tNNPS\tNumber=Plur\t3\tnsubj', '3\tlaunched\tlaunch\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '4\tattacks\tattack\tNOUN\tNNS\tNumber=Plur\t3\tobj', '5\ton\ton\tADP\tIN\t_\t7\tcase', '6\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t7\tdet', '7\tsouth\tsouth\tNOUN\tNN\tNumber=Sing\t4\tnmod', '8\tof\tof\tADP\tIN\t_\t9\tcase', '9\tFrance\tFrance\tPROPN\tNNP\tNumber=Sing\t7\tnmod', '10\t,\t,\tPUNCT\t,\t_\t3\tpunct', '11\tuntil\tuntil\tSCONJ\tIN\t_\t14\tmark', '12\tthey\tthey\tPRON\tPRP\tCase=Nom|Number=Plur|Person=3|PronType=Prs\t14\tnsubj:pass', '13\twere\tbe\tAUX\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t14\taux:pass', '14\tdefeated\tdefeat\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t3\tadvcl', '15\tby\tby\tADP\tIN\t_\t17\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t17\tdet', '17\tFranks\tFranks\tPROPN\tNNPS\tNumber=Sing\t14\tobl', '18\tat\tat\tADP\tIN\t_\t20\tcase', '19\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t20\tdet', '20\tBattle\tBattle\tPROPN\tNNP\tNumber=Sing\t14\tobl', '21\tof\tof\tADP\tIN\t_\t22\tcase', '22\tPoitiers\tPoitiers\tPROPN\tNNP\tNumber=Sing\t20\tnmod', '23\t(\t(\tPUNCT\t-LRB-\t_\t24\tpunct', '24\t732\t732\tNUM\tCD\tNumType=Card\t20\tappos', '25\t)\t)\tPUNCT\t-RRB-\t_\t24\tpunct', '26\t.\t.\tPUNCT\t.\t_\t3\tpunct']], [['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tMusiims\tMusiims\tPROPN\tNNPS\tNumber=Plur\t3\tnsubj', '3\tlaunched\tlaunch\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '4\tattacks\tattack\tNOUN\tNNS\tNumber=Plur\t3\tobj', '5\ton\ton\tADP\tIN\t_\t7\tcase', '6\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t7\tdet', '7\tsouth\tsouth\tNOUN\tNN\tNumber=Sing\t4\tnmod', '8\tof\tof\tADP\tIN\t_\t9\tcase', '9\tFrance\tFrance\tPROPN\tNNP\tNumber=Sing\t7\tnmod', '10\t,\t,\tPUNCT\t,\t_\t3\tpunct', '11\tuntil\tuntil\tSCONJ\tIN\t_\t14\tmark', '12\tthey\tthey\tPRON\tPRP\tCase=Nom|Number=Plur|Person=3|Pron ...
# [[['1\tThey\tthey\tPRON\tPRP\tCase=Nom|Number=Plur|Person=3|PronType=Prs\t2\tnsubj', '2\tcalled\tcall\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '3\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t5\tdet', '4\tconquered\tconquer\tVERB\tVBN\tTense=Past|VerbForm=Part\t5\tamod', '5\tregion\tregion\tNOUN\tNN\tNumber=Sing\t2\tobj', '6\tof\tof\tADP\tIN\t_\t9\tcase', '7\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t9\tdet', '8\tIberian\tiberian\tPROPN\tNNP\tNumber=Sing\t9\tcompound', '9\tPeninsula\tPeninsula\tPROPN\tNNP\tNumber=Sing\t5\tnmod', '10\tal\tal\tPROPN\tNNP\tNumber=Sing\t12\tcompound', '11\t-\t-\tPUNCT\tHYPH\t_\t12\tpunct', '12\tAndalus\tAndalus\tPROPN\tNNP\tNumber=Sing\t9\tappos', '13\t.\t.\tPUNCT\t.\t_\t2\tpunct'], ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']], [['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct'], ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tcapital\tcapital\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\testablished\testablish\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tin\tin\tADP\tIN\t_\t7\tcase', '6\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t7\tdet', '7\tcity\tcity\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\tof\tof\tADP\tIN\t_\t9\tcase', '9\tCordoba\tCordoba\tPROPN\tNNP\tNumber=Sing\t7\tnmod', '10\t.\t.\tPUNCT\t.\t_\t4\tpunct']]]
# 0.0
# 0.0
# 0.1429
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
# ...
# x[0]:
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']
# x[0]:
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']
# x[0]:
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']
# x[0]:
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']
# x[0]:
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']
# x[0]:
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']
# 0.1429
# 0.2
# x[0]:
#
# ['1\tIn\tin\tADP\tIN\t_\t2\tcase', '2\t711\t711\tNUM\tCD\tNumType=Card\t11\tobl', '3\t,\t,\tPUNCT\t,\t_\t11\tpunct', '4\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t6\tdet', '5\tsmall\tsmall\tADJ\tJJ\tDegree=Pos\t6\tamod', '6\tgroup\tgroup\tNOUN\tNN\tNumber=Sing\t11\tnsubj', '7\tof\tof\tADP\tIN\t_\t8\tcase', '8\tArabs\tArabs\tPROPN\tNNPS\tNumber=Plur\t6\tnmod', '9\tand\tand\tCCONJ\tCC\t_\t10\tcc', '10\tBerbers\tberber\tPROPN\tNNPS\tNumber=Plur\t8\tconj', '11\tcrossed\tcross\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '12\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t13\tdet', '13\tStrait\tStrait\tPROPN\tNNP\tNumber=Sing\t11\tobj', '14\tof\tof\tADP\tIN\t_\t15\tcase', '15\tGibraltar\tGibraltar\tPROPN\tNNP\tNumber=Sing\t13\tnmod', '16\tunder\tunder\tADP\tIN\t_\t18\tcase', '17\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '18\tcommand\tcommand\tNOUN\tNN\tNumber=Sing\t11\tobl', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tTariq\tTariq\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t,\t,\tPUNCT\t,\t_\t20\tpunct', '22\tlieutenant\tlieutenant\tNOUN\tNN\tNumber=Sing\t20\tappos', '23\tto\tto\tADP\tIN\t_\t24\tcase', '24\tMuza\tMuza\tPROPN\tNNP\tNumber=Sing\t22\tnmod', '25\t,\t,\tPUNCT\t,\t_\t24\tpunct', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t28\tdet', '27\tMuslim\tMuslim\tPROPN\tNNP\tNumber=Sing\t28\tcompound', '28\tgovernor\tgovernor\tPROPN\tNNP\tNumber=Sing\t20\tappos', '29\tof\tof\tADP\tIN\t_\t31\tcase', '30\tNorth\tNorth\tPROPN\tNNP\tNumber=Sing\t31\tcompound', '31\tAfrica\tAfrica\tPROPN\tNNP\tNumber=Sing\t28\tnmod', '32\t.\t.\tPUNCT\t.\t_\t11\tpunct']
# x[0]:
#
# ['1\tTheir\tthey\tPRON\tPRP$\tNumber=Plur|Person=3|Poss=Yes|PronType=Prs\t2\tnmod:poss', '2\tintention\tintention\tNOUN\tNN\tNumber=Sing\t3\tnsubj', '3\twas\tbe\tVERB\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t0\troot', '4\tto\tto\tPART\tTO\t_\t5\tmark', '5\tloot\tloot\tVERB\tVB\tVerbForm=Inf\t3\tccomp', '6\tand\tand\tCCONJ\tCC\t_\t7\tcc', '7\tplunder\tplunder\tVERB\tVB\tVerbForm=Inf\t5\tconj', '8\t.\t.\tPUNCT\t.\t_\t3\tpunct']
# x[0]:
#
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tPeninsula\tPeninsula\tPROPN\tNNP\tNumber=Sing\t3\tnsubj', '3\toffered\toffer\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '4\tlittle\tlittle\tADJ\tJJ\tDegree=Pos\t5\tamod', '5\tresistance\tresistance\tNOUN\tNN\tNumber=Sing\t3\tobj', '6\tand\tand\tCCONJ\tCC\t_\t9\tcc', '7\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t9\taux:pass', '8\tquickly\tquickly\tADV\tRB\t_\t9\tadvmod', '9\toccupied\toccupy\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t3\tconj', '10\t.\t.\tPUNCT\t.\t_\t3\tpunct']
# x[0]:
#
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t3\tdet', '2\tMuslim\tmuslim\tADJ\tJJ\tDegree=Pos\t3\tamod', '3\tinvasion\tinvasion\tNOUN\tNN\tNumber=Sing\t5\tnsubj:pass', '4\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t5\taux:pass', '5\thalted\thalt\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '6\tin\tin\tADP\tIN\t_\t10\tcase', '7\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t10\tdet', '8\tnorthern\tnorthern\tADJ\tJJ\tDegree=Pos\t10\tamod', '9\tmountainous\tmountainous\tADJ\tJJ\tDegree=Pos\t10\tamod', '10\tregion\tregion\tNOUN\tNN\tNumber=Sing\t5\tobl', '11\t,\t,\tPUNCT\t,\t_\t10\tpunct', '12\twhere\twhere\tADV\tWRB\tPronType=Rel\t18\tadvmod', '13\tcertain\tcertain\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tgroups\tgroup\tNOUN\tNNS\tNumber=Plur\t18\tnsubj', '15\tof\tof\tADP\tIN\t_\t17\tcase', '16\tChristian\tChristian\tPROPN\tNNP\tNumber=Sing\t17\tcompound', '17\tresistaoce\tresistaoce\tNOUN\tNNS\tNumber=Plur\t14\tnmod', '18\temerged\temerge\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t10\tacl:relcl', '19\t,\t,\tPUNCT\t,\t_\t24\tpunct', '20\tand\tand\tCCONJ\tCC\t_\t24\tcc', '21\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t22\tdet', '22\tMuslims\tMuslims\tPROPN\tNNPS\tNumber=Plur\t24\tnsubj:pass', '23\twere\tbe\tAUX\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t24\taux:pass', '24\tdefeated\tdefeat\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t5\tconj', '25\tby\tby\tADP\tIN\t_\t27\tcase', '26\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t27\tdet', '27\tAsturians\tAsturians\tPROPN\tNNPS\tNumber=Plur\t24\tobl', '28\tin\tin\tADP\tIN\t_\t30\tcase', '29\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t30\tdet', '30\tBattle\tBattle\tPROPN\tNNP\tNumber=Sing\t24\tobl', '31\tof\tof\tADP\tIN\t_\t32\tcase', '32\tCovadonga\tCovadonga\tPROPN\tNNP\tNumber=Sing\t30\tnmod', '33\t(\t(\tPUNCT\t-LRB-\t_\t34\tpunct', '34\t722\t722\tNUM\tCD\tNumType=Card\t30\tappos', '35\t)\t)\tPUNCT\t-RRB-\t_\t34\tpunct', '36\t.\t.\tPUNCT\t.\t_\t5\tpunct']
# x[0]:
#
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tMusiims\tMusiims\tPROPN\tNNPS\tNumber=Plur\t3\tnsubj', '3\tlaunched\tlaunch\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '4\tattacks\tattack\tNOUN\tNNS\tNumber=Plur\t3\tobj', '5\ton\ton\tADP\tIN\t_\t7\tcase', '6\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t7\tdet', '7\tsouth\tsouth\tNOUN\tNN\tNumber=Sing\t4\tnmod', '8\tof\tof\tADP\tIN\t_\t9\tcase', '9\tFrance\tFrance\tPROPN\tNNP\tNumber=Sing\t7\tnmod', '10\t,\t,\tPUNCT\t,\t_\t3\tpunct', '11\tuntil\tuntil\tSCONJ\tIN\t_\t14\tmark', '12\tthey\tthey\tPRON\tPRP\tCase=Nom|Number=Plur|Person=3|PronType=Prs\t14\tnsubj:pass', '13\twere\tbe\tAUX\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t14\taux:pass', '14\tdefeated\tdefeat\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t3\tadvcl', '15\tby\tby\tADP\tIN\t_\t17\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t17\tdet', '17\tFranks\tFranks\tPROPN\tNNPS\tNumber=Sing\t14\tobl', '18\tat\tat\tADP\tIN\t_\t20\tcase', '19\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t20\tdet', '20\tBattle\tBattle\tPROPN\tNNP\tNumber=Sing\t14\tobl', '21\tof\tof\tADP\tIN\t_\t22\tcase', '22\tPoitiers\tPoitiers\tPROPN\tNNP\tNumber=Sing\t20\tnmod', '23\t(\t(\tPUNCT\t-LRB-\t_\t24\tpunct', '24\t732\t732\tNUM\tCD\tNumType=Card\t20\tappos', '25\t)\t)\tPUNCT\t-RRB-\t_\t24\tpunct', '26\t.\t.\tPUNCT\t.\t_\t3\tpunct']
# x[0]:
#
# ['1\tThey\tthey\tPRON\tPRP\tCase=Nom|Number=Plur|Person=3|PronType=Prs\t2\tnsubj', '2\tcalled\tcall\tVERB\tVBD\tMood=Ind|Tense=Past|VerbForm=Fin\t0\troot', '3\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t5\tdet', '4\tconquered\tconquer\tVERB\tVBN\tTense=Past|VerbForm=Part\t5\tamod', '5\tregion\tregion\tNOUN\tNN\tNumber=Sing\t2\tobj', '6\tof\tof\tADP\tIN\t_\t9\tcase', '7\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t9\tdet', '8\tIberian\tiberian\tPROPN\tNNP\tNumber=Sing\t9\tcompound', '9\tPeninsula\tPeninsula\tPROPN\tNNP\tNumber=Sing\t5\tnmod', '10\tal\tal\tPROPN\tNNP\tNumber=Sing\t12\tcompound', '11\t-\t-\tPUNCT\tHYPH\t_\t12\tpunct', '12\tAndalus\tAndalus\tPROPN\tNNP\tNumber=Sing\t9\tappos', '13\t.\t.\tPUNCT\t.\t_\t2\tpunct']
# x[0]:
#
# ['1\tThe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t2\tdet', '2\tterritory\tterritory\tNOUN\tNN\tNumber=Sing\t4\tnsubj:pass', '3\twas\tbe\tAUX\tVBD\tMood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin\t4\taux:pass', '4\torganised\torganised\tVERB\tVBN\tTense=Past|VerbForm=Part|Voice=Pass\t0\troot', '5\tas\tas\tADP\tIN\t_\t7\tcase', '6\tan\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t7\tdet', '7\temirate\temirate\tNOUN\tNN\tNumber=Sing\t4\tobl', '8\t,\t,\tPUNCT\t,\t_\t7\tpunct', '9\ta\ta\tDET\tDT\tDefinite=Ind|PronType=Art\t14\tdet', '10\tpolitically\tpolitically\tADV\tRB\t_\t13\tadvmod', '11\tand\tand\tCCONJ\tCC\t_\t13\tcc', '12\treligiously\treligiously\tADV\tRB\t_\t13\tadvmod', '13\tdependent\tdependent\tADJ\tJJ\tDegree=Pos\t14\tamod', '14\tprovince\tprovince\tNOUN\tNN\tNumber=Sing\t7\tappos', '15\tof\tof\tADP\tIN\t_\t18\tcase', '16\tthe\tthe\tDET\tDT\tDefinite=Def|PronType=Art\t18\tdet', '17\tUmayyad\tUmayyad\tPROPN\tNNP\tNumber=Sing\t18\tcompound', '18\tCaliphate\tCaliphate\tPROPN\tNNP\tNumber=Sing\t14\tnmod', '19\tof\tof\tADP\tIN\t_\t20\tcase', '20\tDamascus\tDamascus\tPROPN\tNNP\tNumber=Sing\t18\tnmod', '21\t.\t.\tPUNCT\t.\t_\t4\tpunct']
# 0.0365
# 0.05
# 4.0

# %%
import stanfordnlp
import re
####Numpy
import numpy as np
def process_text(input=None, text=None):
        # quitar todos los retornos \n si contiene
        if input is not None:
            if ".txt" not in input:
                pre_text = textract.process(input)
                text = pre_text.decode()
                text = text.replace('\n', '@')
            else:
                with open(input, encoding='utf-8') as f:
                    text = f.read().replace('\n', '@')
            text = re.sub(r'@+', '', text)
        # remove text inside parentheses
        # text = re.sub(r'\([^)]*\)', '', text)
        # separa , . ! ( ) ? ; del texto con espacios, teniendo en cuenta que los no son numeros en el caso de , y .
        text = re.sub(r'[.]+(?![0-9])', r' . ', text)
        text = re.sub(r'[,]+(?![0-9])', r' , ', text)
        text = re.sub(r"!", " ! ", text)
        text = re.sub(r"\(", " ( ", text)
        text = re.sub(r"\)", " ) ", text)
        text = re.sub(r"\?", " ? ", text)
        text = re.sub(r";", " ; ", text)
        # sustituye 2 espacios seguidos por 1
        text = re.sub(r"\s{2,}", " ", text)
        return text
MODELS_DIR = '.'
stanfordnlp.download('en', MODELS_DIR) # Download the English models
#./en_ewt_models/en_ewt.pretrain.pt
#./en_ewt_models/en_ewt_lemmatizer.pt
#./en_ewt_models/en_ewt_parser.pt
#./en_ewt_models/en_ewt_tagger.pt
#./en_ewt_models/en_ewt_tokenizer.pt
config = {'processors': 'tokenize,mwt,pos,lemma,depparse', # Comma-separated list of processors to use
	'lang': 'en', # Language code for the language to build the Pipeline in
	'tokenize_model_path': './en_ewt_models/en_ewt_tokenizer.pt', # Processor-specific arguments are set with keys "{processor_name}_{argument_name}"
#	'mwt_model_path': './fr_gsd_models/fr_gsd_mwt_expander.pt',
	'pos_model_path': './en_ewt_models/en_ewt_tagger.pt',
	'pos_pretrain_path': './en_ewt_models/en_ewt.pretrain.pt',
	'lemma_model_path': './en_ewt_models/en_ewt_lemmatizer.pt',
	'depparse_model_path': './en_ewt_models/en_ewt_parser.pt',
	'depparse_pretrain_path': './en_ewt_models/en_ewt.pretrain.pt'
}
standford = stanfordnlp.Pipeline(**config) # Initialize the pipeline using a configuration dict
#standford = stanfordnlp.Pipeline() # This sets up a default neural pipeline in English
input="Loterry-adv.txt"#sys.argv[1]
with open(input, encoding='utf-8') as f:
        text = f.read().replace('\n', '@')
#Si varios enters consecutivos en uno
text = re.sub(r'@+', '@', text)
#lines es una lista de parrafos
lines = text.split('@')
paragraphs = []
for line in lines:
        #si no es una linea vacia, añade en parrafos
        if not line.strip() == '':
            #Lista de texto formado por parrafos
            paragraphs.append(line)
            
for paragraph in paragraphs:
     #Parrafo a objeto doc Document object
     doc = standford(process_text(text=paragraph))
     ##doc.sentences es una lista de objectos sentence [doc.sentence1, doc.sentence2, ...]
     #hay que conseguir:[[sent1],[sent2],...[sentN]]
     for sent in doc.sentences:
        for word in sent.words:
            #print(word.__dict__)
            #print(word.text+"\t"+word.lemma+"\t"+word.upos+"\t"+word.xpos+"\n")
            print(str(word.index)+"\t"+word.text+"\t"+word.lemma+"\t"+word.upos+"\t"+word.xpos+"\t"+word.feats+"\t"+str(word.governor)+"\t"+str(word.dependency_relation)+"\n")
            #print(*[f'text: {word.text+" "}\tlemma: {word.lemma}\tupos: {word.upos}\txpos: {word.xpos}' for sent in doc.sentences for word in sent.words], sep='\n')
            #doc.sentences[0].print_dependencies()
# Out:
# Using the default treebank "en_ewt" for language "en".
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': './en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': './en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': './en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': './en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': './en_ewt_models/en_ewt_parser.pt', 'pretrain_path': './en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det
#
# 2	balls	ball	NOUN	NNS	Number=Plur	4	nsubj
#
# 3	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	4	aux
#
# 4	dropped	drop	VERB	VBN	Tense=Past|VerbForm=Part	0	root
#
# 5	down	down	ADP	RP	_	4	compound:prt
#
# 6	the	the	DET	DT	Definite=Def|PronType=Art	7	det
#
# 7	chute	chute	NOUN	NN	Number=Sing	4	obj
#
# 8	and	and	CCONJ	CC	_	12	cc
#
# 9	all	all	DET	DT	_	12	det
#
# 10	six	six	NUM	CD	NumType=Card	11	nummod
#
# 11	numbers	number	NOUN	NNS	Number=Plur	12	compound
#
# 12	match	match	NOUN	NN	Number=Sing	4	conj
#
# 13	,	,	PUNCT	,	_	4	punct
#
# 14	so	so	ADV	RB	_	17	advmod
#
# 15	it	it	PRON	PRP	Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs	17	nsubj
#
# 16	s	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	17	cop
#
# 17	time	time	NOUN	NN	Number=Sing	4	parataxis
#
# 18	to	to	PART	TO	_	19	mark
#
# 19	buy	buy	VERB	VB	VerbForm=Inf	17	acl
#
# 20	that	that	DET	DT	Number=Sing|PronType=Dem	21	det
#
# 21	Audi	Audi	PROPN	NNP	Number=Sing	19	obj
#
# 22	,	,	PUNCT	,	_	23	punct
#
# 23	book	book	VERB	VB	VerbForm=Inf	19	conj
#
# 24	the	the	DET	DT	Definite=Def|PronType=Art	25	det
#
# 25	holiday	holiday	NOUN	NN	Number=Sing	23	obj
#
# 26	in	in	ADP	IN	_	28	case
#
# 27	the	the	DET	DT	Definite=Def|PronType=Art	28	det
#
# 28	US	US	PROPN	NNP	Number=Sing	23	obl
#
# 29	and	and	CCONJ	CC	_	30	cc
#
# 30	phone	phone	VERB	VB	VerbForm=Inf	19	conj
#
# 31	the	the	DET	DT	Definite=Def|PronType=Art	33	det
#
# 32	estate	estate	NOUN	NN	Number=Sing	33	compound
#
# 33	agent	agent	NOUN	NN	Number=Sing	30	obj
#
# 34	.	.	PUNCT	.	_	4	punct
#
# 1	At	at	ADV	RB	_	6	advmod
#
# 2	least	least	ADV	RBS	Degree=Sup	1	fixed
#
# 3	,	,	PUNCT	,	_	6	punct
#
# 4	that	that	PRON	DT	Number=Sing|PronType=Dem	6	nsubj
#
# 5	s	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	6	cop
#
# 6	what	what	PRON	WP	PronType=Int	0	root
#
# 7	most	most	ADJ	JJS	Degree=Sup	9	amod
#
# 8	lottery	lottery	NOUN	NN	Number=Sing	9	compound
#
# 9	millionaires	millionaire	NOUN	NNS	Number=Plur	10	nsubj
#
# 10	do	do	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	6	acl:relcl
#
# 11	,	,	PUNCT	,	_	6	punct
#
# 12	according	accord	VERB	VBG	VerbForm=Ger	15	case
#
# 13	to	to	ADP	IN	_	12	fixed
#
# 14	an	a	DET	DT	Definite=Ind|PronType=Art	15	det
#
# 15	analysis	analysis	NOUN	NN	Number=Sing	6	obl
#
# 16	of	of	ADP	IN	_	17	case
#
# 17	spending	spending	NOUN	NN	Number=Sing	15	nmod
#
# 18	and	and	CCONJ	CC	_	19	cc
#
# 19	investment	investment	NOUN	NN	Number=Sing	17	conj
#
# 20	by	by	ADP	IN	_	22	case
#
# 21	jackpot	jackpot	NOUN	NN	Number=Sing	22	compound
#
# 22	winners	winner	NOUN	NNS	Number=Plur	17	nmod
#
# 23	.	.	PUNCT	.	_	6	punct
#
# 1	Since	since	ADP	IN	_	3	case
#
# 2	its	its	PRON	PRP$	Gender=Neut|Number=Sing|Person=3|Poss=Yes|PronType=Prs	3	nmod:poss
#
# 3	launch	launch	NOUN	NN	Number=Sing	10	obl
#
# 4	in	in	ADP	IN	_	5	case
#
# 5	1994	1994	NUM	CD	NumType=Card	3	nmod
#
# 6	,	,	PUNCT	,	_	10	punct
#
# 7	the	the	DET	DT	Definite=Def|PronType=Art	8	det
#
# 8	lottery	lottery	NOUN	NN	Number=Sing	10	nsubj
#
# 9	has	have	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	10	aux
#
# 10	created	create	VERB	VBN	Tense=Past|VerbForm=Part	0	root
#
# 11	3,000	3,000	NUM	CD	NumType=Card	12	nummod
#
# 12	millionaires	millionaire	NOUN	NNS	Number=Plur	10	obj
#
# 13	who	who	PRON	WP	PronType=Rel	15	nsubj
#
# 14	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	15	aux
#
# 15	won	win	VERB	VBN	Tense=Past|VerbForm=Part	12	acl:relcl
#
# 16	more	more	ADJ	JJR	Degree=Cmp	18	advmod
#
# 17	than	than	ADP	IN	_	16	fixed
#
# 18	8.5	8.5	NUM	CD	NumType=Card	19	compound
#
# 19	bn	bn	NUM	CD	NumType=Card	15	obj
#
# 20	in	in	ADP	IN	_	21	case
#
# 21	total	total	ADJ	JJ	Degree=Pos	15	obl
#
# 22	,	,	PUNCT	,	_	15	punct
#
# 23	at	at	ADP	IN	_	25	case
#
# 24	an	a	DET	DT	Definite=Ind|PronType=Art	25	det
#
# 25	average	average	NOUN	NN	Number=Sing	15	obl
#
# 26	of	of	ADP	IN	_	28	case
#
# 27	2.8	2.8	NUM	CD	NumType=Card	28	compound
#
# 28	m	m	NUM	CD	NumType=Card	25	nmod
#
# 29	each	each	DET	DT	_	25	nmod
#
# 30	.	.	PUNCT	.	_	10	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	5	det
#
# 2	trickle	trickle	NOUN	NN	Number=Sing	4	compound
#
# 3	-	-	PUNCT	HYPH	_	4	punct
#
# 4	down	down	NOUN	NN	Number=Sing	5	compound
#
# 5	effect	effect	NOUN	NN	Number=Sing	6	nsubj
#
# 6	means	mean	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root
#
# 7	that	that	SCONJ	IN	_	12	mark
#
# 8	between	between	ADP	IN	_	9	case
#
# 9	them	they	PRON	PRP	Case=Acc|Number=Plur|Person=3|PronType=Prs	12	obl
#
# 10	they	they	PRON	PRP	Case=Nom|Number=Plur|Person=3|PronType=Prs	12	nsubj
#
# 11	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	12	aux
#
# 12	created	create	VERB	VBN	Tense=Past|VerbForm=Part	6	ccomp
#
# 13	a	a	DET	DT	Definite=Ind|PronType=Art	16	det
#
# 14	further	further	ADJ	JJ	Degree=Pos	16	amod
#
# 15	3,780	3,780	NUM	CD	NumType=Card	16	nummod
#
# 16	millionaires	millionaire	NOUN	NNS	Number=Plur	12	obj
#
# 17	among	among	ADP	IN	_	19	case
#
# 18	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	19	nmod:poss
#
# 19	children	child	NOUN	NNS	Number=Plur	16	nmod
#
# 20	,	,	PUNCT	,	_	21	punct
#
# 21	family	family	NOUN	NN	Number=Sing	19	conj
#
# 22	and	and	CCONJ	CC	_	23	cc
#
# 23	friends	friend	NOUN	NNS	Number=Plur	19	conj
#
# 24	,	,	PUNCT	,	_	12	punct
#
# 25	according	accord	VERB	VBG	VerbForm=Ger	28	case
#
# 26	to	to	ADP	IN	_	25	fixed
#
# 27	the	the	DET	DT	Definite=Def|PronType=Art	28	det
#
# 28	authors	author	NOUN	NNS	Number=Plur	12	obl
#
# 29	of	of	ADP	IN	_	31	case
#
# 30	the	the	DET	DT	Definite=Def|PronType=Art	31	det
#
# 31	study	study	NOUN	NN	Number=Sing	28	nmod
#
# 32	,	,	PUNCT	,	_	31	punct
#
# 33	Oxford	Oxford	PROPN	NNP	Number=Sing	34	compound
#
# 34	Economics	economics	PROPN	NNPS	Number=Plur	31	conj
#
# 35	.	.	PUNCT	.	_	6	punct
#
# 1	Most	most	ADJ	JJS	Degree=Sup	2	amod
#
# 2	winners	winner	NOUN	NNS	Number=Plur	7	nsubj
#
# 3	(	(	PUNCT	-LRB-	_	5	punct
#
# 4	59	59	NUM	CD	NumType=Card	5	nummod
#
# 5	%	%	SYM	NN	Number=Sing	2	appos
#
# 6	)	)	PUNCT	-RRB-	_	5	punct
#
# 7	give	give	VERB	VB	Mood=Ind|VerbForm=Fin	0	root
#
# 8	up	up	ADP	RP	_	7	compound:prt
#
# 9	work	work	NOUN	NN	Number=Sing	7	obj
#
# 10	straight	straight	ADV	RB	_	11	advmod
#
# 11	away	away	ADV	RB	_	7	advmod
#
# 12	,	,	PUNCT	,	_	16	punct
#
# 13	but	but	CCONJ	CC	_	16	cc
#
# 14	19	19	NUM	CD	NumType=Card	15	nummod
#
# 15	%	%	SYM	NN	Number=Sing	16	nsubj
#
# 16	carry	carry	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	7	conj
#
# 17	on	on	SCONJ	IN	_	18	mark
#
# 18	doing	do	VERB	VBG	VerbForm=Ger	16	advcl
#
# 19	the	the	DET	DT	Definite=Def|PronType=Art	21	det
#
# 20	day	day	NOUN	NN	Number=Sing	21	compound
#
# 21	job	job	NOUN	NN	Number=Sing	18	obj
#
# 22	and	and	CCONJ	CC	_	25	cc
#
# 23	31	31	NUM	CD	NumType=Card	24	nummod
#
# 24	%	%	SYM	NN	Number=Sing	25	nsubj
#
# 25	do	do	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	16	conj
#
# 26	unpaid	unpaid	ADJ	JJ	Degree=Pos	28	amod
#
# 27	voluntary	voluntary	ADJ	JJ	Degree=Pos	28	amod
#
# 28	work	work	NOUN	NN	Number=Sing	25	obj
#
# 29	.	.	PUNCT	.	_	7	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	3	det
#
# 2	good	good	ADJ	JJ	Degree=Pos	3	amod
#
# 3	news	news	NOUN	NN	Number=Sing	7	nsubj
#
# 4	for	for	ADP	IN	_	6	case
#
# 5	the	the	DET	DT	Definite=Def|PronType=Art	6	det
#
# 6	economy	economy	NOUN	NN	Number=Sing	3	nmod
#
# 7	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root
#
# 8	that	that	SCONJ	IN	_	14	mark
#
# 9	98	98	NUM	CD	NumType=Card	10	nummod
#
# 10	%	%	SYM	NN	Number=Sing	14	nsubj
#
# 11	of	of	ADP	IN	_	13	case
#
# 12	winners	winner	NOUN	NNS	Number=Plur	13	compound
#
# 13	spending	spending	NOUN	NN	Number=Sing	10	nmod
#
# 14	remained	remain	VERB	VBD	Tense=Past|VerbForm=Fin	7	ccomp
#
# 15	in	in	ADP	IN	_	17	case
#
# 16	the	the	DET	DT	Definite=Def|PronType=Art	17	det
#
# 17	UK	UK	PROPN	NNP	Number=Sing	14	obl
#
# 18	.	.	PUNCT	.	_	7	punct
#
# 1	Through	through	ADP	IN	_	3	case
#
# 2	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	3	nmod:poss
#
# 3	spending	spending	NOUN	NN	Number=Sing	13	obl
#
# 4	on	on	ADP	IN	_	5	case
#
# 5	property	property	NOUN	NN	Number=Sing	3	nmod
#
# 6	,	,	PUNCT	,	_	7	punct
#
# 7	vehicles	vehicle	NOUN	NNS	Number=Plur	5	conj
#
# 8	and	and	CCONJ	CC	_	9	cc
#
# 9	holidays	holiday	NOUN	NNS	Number=Plur	5	conj
#
# 10	,	,	PUNCT	,	_	13	punct
#
# 11	it	it	PRON	PRP	Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs	13	nsubj:pass
#
# 12	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	13	aux:pass
#
# 13	estimated	estimate	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	0	root
#
# 14	that	that	SCONJ	IN	_	17	mark
#
# 15	each	each	DET	DT	_	16	det
#
# 16	winner	winner	NOUN	NN	Number=Sing	17	nsubj
#
# 17	keeps	keep	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	13	ccomp
#
# 18	six	six	NUM	CD	NumType=Card	19	nummod
#
# 19	people	people	NOUN	NNS	Number=Plur	17	obj
#
# 20	in	in	ADP	IN	_	25	case
#
# 21	a	a	DET	DT	Definite=Ind|PronType=Art	25	det
#
# 22	full	full	ADJ	JJ	Degree=Pos	24	amod
#
# 23	-	-	PUNCT	HYPH	_	24	punct
#
# 24	time	time	NOUN	NN	Number=Sing	25	compound
#
# 25	job	job	NOUN	NN	Number=Sing	17	obl
#
# 26	for	for	ADP	IN	_	28	case
#
# 27	a	a	DET	DT	Definite=Ind|PronType=Art	28	det
#
# 28	year	year	NOUN	NN	Number=Sing	17	obl
#
# 29	.	.	PUNCT	.	_	13	punct
# 1	Winners	winner	NOUN	NNS	Number=Plur	3	nsubj
#
# 2	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	3	aux
#
# 3	contributed	contribute	VERB	VBN	Tense=Past|VerbForm=Part	0	root
#
# 4	almost	almost	ADV	RB	_	5	advmod
#
# 5	750	750	NUM	CD	NumType=Card	6	compound
#
# 6	m	m	NUM	CD	NumType=Card	3	obj
#
# 7	to	to	ADP	IN	_	10	case
#
# 8	gross	gross	ADJ	JJ	Degree=Pos	10	amod
#
# 9	domestic	domestic	ADJ	JJ	Degree=Pos	10	amod
#
# 10	product	product	NOUN	NN	Number=Sing	3	obl
#
# 11	(	(	PUNCT	-LRB-	_	12	punct
#
# 12	GDP	gdp	NOUN	NN	Number=Sing	10	appos
#
# 13	)	)	PUNCT	-RRB-	_	12	punct
#
# 14	,	,	PUNCT	,	_	16	punct
#
# 15	and	and	CCONJ	CC	_	16	cc
#
# 16	generated	generate	VERB	VBN	Tense=Past|VerbForm=Part	3	conj
#
# 17	more	more	ADJ	JJR	Degree=Cmp	19	advmod
#
# 18	than	than	ADP	IN	_	17	fixed
#
# 19	500	500	NUM	CD	NumType=Card	20	compound
#
# 20	m	m	NUM	CD	NumType=Card	16	obj
#
# 21	in	in	ADP	IN	_	23	case
#
# 22	tax	tax	NOUN	NN	Number=Sing	23	compound
#
# 23	receipts	receipt	NOUN	NNS	Number=Plur	16	obl
#
# 24	for	for	ADP	IN	_	26	case
#
# 25	the	the	DET	DT	Definite=Def|PronType=Art	26	det
#
# 26	Exchequer	Exchequer	NOUN	NN	Number=Sing	23	nmod
#
# 27	.	.	PUNCT	.	_	3	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det
#
# 2	bulk	bulk	NOUN	NN	Number=Sing	6	nsubj
#
# 3	of	of	ADP	IN	_	5	case
#
# 4	the	the	DET	DT	Definite=Def|PronType=Art	5	det
#
# 5	money	money	NOUN	NN	Number=Sing	2	nmod
#
# 6	went	go	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root
#
# 7	on	on	ADP	IN	_	8	case
#
# 8	property	property	NOUN	NN	Number=Sing	6	obl
#
# 9	,	,	PUNCT	,	_	6	punct
#
# 10	with	with	ADP	IN	_	12	case
#
# 11	2.72	2.72	NUM	CD	NumType=Card	12	compound
#
# 12	bn	bn	NUM	CD	NumType=Card	13	obl
#
# 13	spent	spend	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	6	conj
#
# 14	on	on	ADP	IN	_	15	case
#
# 15	winners	winner	NOUN	NNS	Number=Plur	13	obl
#
# 16	main	main	ADJ	JJ	Degree=Pos	17	amod
#
# 17	properties	property	NOUN	NNS	Number=Plur	13	obl
#
# 18	,	,	PUNCT	,	_	21	punct
#
# 19	and	and	CCONJ	CC	_	21	cc
#
# 20	170	170	NUM	CD	NumType=Card	21	nummod
#
# 21	m	m	NUM	CD	NumType=Card	17	conj
#
# 22	in	in	SCONJ	IN	_	23	mark
#
# 23	paying	pay	VERB	VBG	VerbForm=Ger	21	advcl
#
# 24	off	off	ADP	RP	_	23	compound:prt
#
# 25	existing	exist	VERB	VBG	VerbForm=Ger	26	amod
#
# 26	debt	debt	NOUN	NN	Number=Sing	23	obj
#
# 27	and	and	CCONJ	CC	_	28	cc
#
# 28	mortgages	mortgage	NOUN	NNS	Number=Plur	26	conj
#
# 29	.	.	PUNCT	.	_	6	punct
#
# 1	Maintaining	maintain	VERB	VBG	VerbForm=Ger	5	csubj
#
# 2	income	income	NOUN	NN	Number=Sing	1	obj
#
# 3	was	be	AUX	VBD	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	5	cop
#
# 4	a	a	DET	DT	Definite=Ind|PronType=Art	5	det
#
# 5	priority	priority	NOUN	NN	Number=Sing	0	root
#
# 6	,	,	PUNCT	,	_	5	punct
#
# 7	with	with	ADP	IN	_	9	case
#
# 8	2.125	2.125	NUM	CD	NumType=Card	9	compound
#
# 9	bn	bn	NUM	CD	NumType=Card	10	nsubj
#
# 10	spent	spend	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	5	advcl
#
# 11	on	on	ADP	IN	_	12	case
#
# 12	investments	investment	NOUN	NNS	Number=Plur	10	obl
#
# 13	.	.	PUNCT	.	_	5	punct
#
# 1	Gifts	Gifts	NOUN	NNS	Number=Plur	6	nsubj
#
# 2	to	to	ADP	IN	_	3	case
#
# 3	family	family	NOUN	NN	Number=Sing	1	nmod
#
# 4	and	and	CCONJ	CC	_	5	cc
#
# 5	friends	friend	NOUN	NNS	Number=Plur	3	conj
#
# 6	accounted	account	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root
#
# 7	for	for	ADP	IN	_	9	case
#
# 8	1.17	1.17	NUM	CD	NumType=Card	9	nummod
#
# 9	bn	bn	NUM	CD	NumType=Card	6	obl
#
# 10	,	,	PUNCT	,	_	15	punct
#
# 11	and	and	CCONJ	CC	_	15	cc
#
# 12	680	680	NUM	CD	NumType=Card	13	nummod
#
# 13	m	m	NOUN	NN	Number=Sing	15	nsubj:pass
#
# 14	was	be	AUX	VBD	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	15	aux:pass
#
# 15	spent	spend	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	6	conj
#
# 16	on	on	ADP	IN	_	17	case
#
# 17	cars	car	NOUN	NNS	Number=Plur	15	obl
#
# 18	and	and	CCONJ	CC	_	19	cc
#
# 19	holidays	holiday	NOUN	NNS	Number=Plur	17	conj
#
# 20	.	.	PUNCT	.	_	6	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det
#
# 2	study	study	NOUN	NN	Number=Sing	25	nsubj:pass
#
# 3	,	,	PUNCT	,	_	2	punct
#
# 4	commissioned	commission	VERB	VBN	Tense=Past|VerbForm=Part	2	acl
#
# 5	by	by	ADP	IN	_	6	case
#
# 6	Camelot	Camelot	PROPN	NNP	Number=Sing	4	obl
#
# 7	,	,	PUNCT	,	_	2	punct
#
# 8	the	the	DET	DT	Definite=Def|PronType=Art	9	det
#
# 9	operators	operator	NOUN	NNS	Number=Plur	2	appos
#
# 10	of	of	ADP	IN	_	14	case
#
# 11	the	the	DET	DT	Definite=Def|PronType=Art	14	det
#
# 12	UK	UK	PROPN	NNP	Number=Sing	14	compound
#
# 13	National	National	PROPN	NNP	Number=Sing	14	compound
#
# 14	Lottery	lottery	PROPN	NNP	Number=Sing	9	nmod
#
# 15	,	,	PUNCT	,	_	17	punct
#
# 16	to	to	PART	TO	_	17	mark
#
# 17	mark	mark	VERB	VB	VerbForm=Inf	9	acl
#
# 18	the	the	DET	DT	Definite=Def|PronType=Art	22	det
#
# 19	3,000	3,000	NUM	CD	NumType=Card	21	nummod
#
# 20	-	-	PUNCT	HYPH	_	21	punct
#
# 21	winners	winner	NOUN	NNS	Number=Plur	22	compound
#
# 22	milestone	milestone	NOUN	NN	Number=Sing	17	obj
#
# 23	,	,	PUNCT	,	_	25	punct
#
# 24	was	be	AUX	VBD	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	25	aux:pass
#
# 25	based	base	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	0	root
#
# 26	on	on	ADP	IN	_	27	case
#
# 27	research	research	NOUN	NN	Number=Sing	25	obl
#
# 28	from	from	ADP	IN	_	34	case
#
# 29	100	100	NUM	CD	NumType=Card	31	compound
#
# 30	1	1	NUM	CD	NumType=Card	31	compound
#
# 31	m	m	NUM	CD	NumType=Card	34	nummod
#
# 32	-	-	PUNCT	HYPH	_	34	punct
#
# 33	plus	plus	CCONJ	CC	_	34	cc
#
# 34	winners	winner	NOUN	NNS	Number=Plur	27	nmod
#
# 35	.	.	PUNCT	.	_	25	punct
#
# 1	It	it	PRON	PRP	Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs	2	nsubj
#
# 2	found	find	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root
#
# 3	that	that	SCONJ	IN	_	10	mark
#
# 4	in	in	ADP	IN	_	5	case
#
# 5	total	total	ADJ	JJ	Degree=Pos	10	obl
#
# 6	the	the	DET	DT	Definite=Def|PronType=Art	8	det
#
# 7	3,000	3,000	NUM	CD	NumType=Card	8	nummod
#
# 8	winners	winner	NOUN	NNS	Number=Plur	10	nsubj
#
# 9	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	10	aux
#
# 10	purchased	purchase	VERB	VBN	Tense=Past|VerbForm=Part	2	ccomp
#
# 11	7,958	7,958	NUM	CD	NumType=Card	12	nummod
#
# 12	houses	house	NOUN	NNS	Number=Plur	10	obj
#
# 13	or	or	CCONJ	CC	_	14	cc
#
# 14	flats	flat	NOUN	NNS	Number=Plur	12	conj
#
# 15	in	in	ADP	IN	_	17	case
#
# 16	the	the	DET	DT	Definite=Def|PronType=Art	17	det
#
# 17	UK	UK	PROPN	NNP	Number=Sing	10	obl
#
# 18	,	,	PUNCT	,	_	21	punct
#
# 19	or	or	CCONJ	CC	_	21	cc
#
# 20	2.7	2.7	NUM	CD	NumType=Card	21	nummod
#
# 21	each	each	DET	DT	_	12	conj
#
# 22	,	,	PUNCT	,	_	10	punct
#
# 23	spending	spend	VERB	VBG	VerbForm=Ger	10	advcl
#
# 24	3.3	3.3	NUM	CD	NumType=Card	25	compound
#
# 25	bn	bn	NUM	CD	NumType=Card	23	obj
#
# 26	.	.	PUNCT	.	_	2	punct
#
# 1	Most	most	ADJ	JJS	Degree=Sup	2	amod
#
# 2	winners	winner	NOUN	NNS	Number=Plur	7	nsubj
#
# 3	(	(	PUNCT	-LRB-	_	5	punct
#
# 4	82	82	NUM	CD	NumType=Card	5	nummod
#
# 5	%	%	SYM	NN	Number=Sing	2	appos
#
# 6	)	)	PUNCT	-RRB-	_	5	punct
#
# 7	changed	change	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root
#
# 8	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	10	nmod:poss
#
# 9	main	main	ADJ	JJ	Degree=Pos	10	amod
#
# 10	residence	residence	NOUN	NN	Number=Sing	7	obj
#
# 11	,	,	PUNCT	,	_	7	punct
#
# 12	spending	spend	VERB	VBG	VerbForm=Ger	7	advcl
#
# 13	an	a	DET	DT	Definite=Ind|PronType=Art	15	det
#
# 14	average	average	ADJ	JJ	Degree=Pos	15	amod
#
# 15	900,000	900,000	NUM	CD	NumType=Card	12	obj
#
# 16	.	.	PUNCT	.	_	7	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	3	det
#
# 2	new	new	ADJ	JJ	Degree=Pos	3	amod
#
# 3	home	home	NOUN	NN	Number=Sing	5	nsubj
#
# 4	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	cop
#
# 5	likely	likely	ADJ	JJ	Degree=Pos	0	root
#
# 6	to	to	PART	TO	_	7	mark
#
# 7	come	come	VERB	VB	VerbForm=Inf	5	xcomp
#
# 8	with	with	ADP	IN	_	11	case
#
# 9	a	a	DET	DT	Definite=Ind|PronType=Art	11	det
#
# 10	hot	hot	ADJ	JJ	Degree=Pos	11	amod
#
# 11	tub	tub	NOUN	NN	Number=Sing	7	obl
#
# 12	,	,	PUNCT	,	_	7	punct
#
# 13	with	with	ADP	IN	_	21	mark
#
# 14	almost	almost	ADV	RB	_	19	advmod
#
# 15	a	a	DET	DT	Definite=Ind|PronType=Art	19	det
#
# 16	third	third	ADJ	JJ	Degree=Pos|NumType=Ord	19	amod
#
# 17	(	(	PUNCT	-LRB-	_	19	punct
#
# 18	29	29	NUM	CD	NumType=Card	19	nummod
#
# 19	%	%	SYM	NN	Number=Sing	7	obl
#
# 20	)	)	PUNCT	-RRB-	_	19	punct
#
# 21	putting	put	VERB	VBG	VerbForm=Ger	7	advcl
#
# 22	that	that	PRON	DT	Number=Sing|PronType=Dem	21	obj
#
# 23	on	on	ADP	IN	_	26	case
#
# 24	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	26	nmod:poss
#
# 25	shopping	shopping	NOUN	NN	Number=Sing	26	compound
#
# 26	list	list	NOUN	NN	Number=Sing	21	obl
#
# 27	.	.	PUNCT	.	_	5	punct
#
# 1	A	a	DET	DT	Definite=Ind|PronType=Art	5	det
#
# 2	walk	walk	NOUN	NN	Number=Sing	5	compound
#
# 3	-	-	PUNCT	HYPH	_	2	punct
#
# 4	in	in	ADP	RP	_	2	compound:prt
#
# 5	wardrobe	wardrobe	NOUN	NN	Number=Sing	8	nsubj
#
# 6	was	be	AUX	VBD	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	8	cop
#
# 7	a	a	DET	DT	Definite=Ind|PronType=Art	8	det
#
# 8	must	must	NOUN	NN	Number=Sing	0	root
#
# 9	for	for	ADP	IN	_	11	case
#
# 10	28	28	NUM	CD	NumType=Card	11	nummod
#
# 11	%	%	SYM	NN	Number=Sing	8	nmod
#
# 12	,	,	PUNCT	,	_	8	punct
#
# 13	almost	almost	ADV	RB	_	15	advmod
#
# 14	a	a	DET	DT	Definite=Ind|PronType=Art	15	det
#
# 15	quarter	quarter	NOUN	NN	Number=Sing	20	nsubj
#
# 16	(	(	PUNCT	-LRB-	_	18	punct
#
# 17	24	24	NUM	CD	NumType=Card	18	nummod
#
# 18	%	%	SYM	NN	Number=Sing	15	appos
#
# 19	)	)	PUNCT	-RRB-	_	18	punct
#
# 20	opted	opt	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	8	conj
#
# 21	for	for	ADP	IN	_	23	case
#
# 22	a	a	DET	DT	Definite=Ind|PronType=Art	23	det
#
# 23	property	property	NOUN	NN	Number=Sing	20	obl
#
# 24	behind	behind	ADP	IN	_	26	case
#
# 25	electric	electric	ADJ	JJ	Degree=Pos	26	amod
#
# 26	gates	gate	NOUN	NNS	Number=Plur	23	nmod
#
# 27	,	,	PUNCT	,	_	31	punct
#
# 28	and	and	CCONJ	CC	_	31	cc
#
# 29	22	22	NUM	CD	NumType=Card	30	nummod
#
# 30	%	%	SYM	NN	Number=Sing	31	nsubj
#
# 31	had	have	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	20	conj
#
# 32	a	a	DET	DT	Definite=Ind|PronType=Art	34	det
#
# 33	games	game	NOUN	NNS	Number=Plur	34	compound
#
# 34	room	room	NOUN	NN	Number=Sing	31	obj
#
# 35	,	,	PUNCT	,	_	31	punct
#
# 36	with	with	ADP	IN	_	38	case
#
# 37	7	7	NUM	CD	NumType=Card	38	nummod
#
# 38	%	%	SYM	NN	Number=Sing	31	obl
#
# 39	installing	install	VERB	VBG	VerbForm=Ger	38	acl
#
# 40	a	a	DET	DT	Definite=Ind|PronType=Art	42	det
#
# 41	snooker	snooker	NOUN	NN	Number=Sing	42	compound
#
# 42	table	table	NOUN	NN	Number=Sing	39	obj
#
# 43	.	.	PUNCT	.	_	8	punct
# 1	Larger	larger	ADJ	JJR	Degree=Cmp	2	amod
#
# 2	properties	property	NOUN	NNS	Number=Plur	3	nsubj
#
# 3	need	need	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	0	root
#
# 4	maintaining	maintain	VERB	VBG	VerbForm=Ger	3	xcomp
#
# 5	,	,	PUNCT	,	_	8	punct
#
# 6	and	and	CCONJ	CC	_	8	cc
#
# 7	30	30	NUM	CD	NumType=Card	8	nummod
#
# 8	%	%	SYM	NN	Number=Sing	4	conj
#
# 9	of	of	ADP	IN	_	10	case
#
# 10	winners	winner	NOUN	NNS	Number=Plur	8	nmod
#
# 11	employed	employ	VERB	VBN	Tense=Past|VerbForm=Part	8	acl
#
# 12	a	a	DET	DT	Definite=Ind|PronType=Art	13	det
#
# 13	cleaner	cleaner	NOUN	NN	Number=Sing	11	obj
#
# 14	and	and	CCONJ	CC	_	16	cc
#
# 15	24	24	NUM	CD	NumType=Card	16	nummod
#
# 16	%	%	SYM	NN	Number=Sing	18	compound
#
# 17	a	a	DET	DT	Definite=Ind|PronType=Art	18	det
#
# 18	gardener	gardener	NOUN	NN	Number=Sing	13	conj
#
# 19	.	.	PUNCT	.	_	3	punct
#
# 1	A	a	DET	DT	Definite=Ind|PronType=Art	3	det
#
# 2	small	small	ADJ	JJ	Degree=Pos	3	amod
#
# 3	proportion	proportion	NOUN	NN	Number=Sing	8	nsubj
#
# 4	(	(	PUNCT	-LRB-	_	6	punct
#
# 5	5	5	NUM	CD	NumType=Card	6	nummod
#
# 6	%	%	SYM	NN	Number=Sing	3	appos
#
# 7	)	)	PUNCT	-RRB-	_	6	punct
#
# 8	employed	employ	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root
#
# 9	a	a	DET	DT	Definite=Ind|PronType=Art	10	det
#
# 10	beautician	beautician	NOUN	NN	Number=Sing	8	obj
#
# 11	.	.	PUNCT	.	_	8	punct
#
# 1	Audis	Audis	NOUN	NNS	Number=Plur	5	nsubj
#
# 2	were	be	AUX	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	5	cop
#
# 3	the	the	DET	DT	Definite=Def|PronType=Art	5	det
#
# 4	favourite	favourite	ADJ	JJ	Degree=Pos	5	amod
#
# 5	cars	car	NOUN	NNS	Number=Plur	0	root
#
# 6	of	of	ADP	IN	_	8	case
#
# 7	16	16	NUM	CD	NumType=Card	8	nummod
#
# 8	%	%	SYM	NN	Number=Sing	5	nmod
#
# 9	of	of	ADP	IN	_	10	case
#
# 10	winners	winner	NOUN	NNS	Number=Plur	8	nmod
#
# 11	,	,	PUNCT	,	_	5	punct
#
# 12	with	with	ADP	IN	_	14	case
#
# 13	Range	Range	PROPN	NNP	Number=Sing	14	compound
#
# 14	Rovers	Rovers	PROPN	NNPS	Number=Plur	8	nmod
#
# 15	and	and	CCONJ	CC	_	16	cc
#
# 16	BMWs	BMWs	PROPN	NNPS	Number=Plur	14	conj
#
# 17	also	also	ADV	RB	_	19	advmod
#
# 18	popular	popular	ADJ	JJ	Degree=Pos	19	amod
#
# 19	purchases	purchase	NOUN	NNS	Number=Plur	14	conj
#
# 20	(	(	PUNCT	-LRB-	_	22	punct
#
# 21	11	11	NUM	CD	NumType=Card	22	nummod
#
# 22	%	%	SYM	NN	Number=Sing	19	appos
#
# 23	each	each	DET	DT	_	22	advmod
#
# 24	)	)	PUNCT	-RRB-	_	22	punct
#
# 25	,	,	PUNCT	,	_	29	punct
#
# 26	as	as	ADV	RB	_	29	cc
#
# 27	well	well	ADV	RB	Degree=Pos	26	fixed
#
# 28	as	as	ADP	IN	_	26	fixed
#
# 29	Mercedes	mercede	PROPN	NNPS	Number=Plur	14	conj
#
# 30	(	(	PUNCT	-LRB-	_	32	punct
#
# 31	10	10	NUM	CD	NumType=Card	32	nummod
#
# 32	%	%	SYM	NN	Number=Sing	29	appos
#
# 33	)	)	PUNCT	-RRB-	_	32	punct
#
# 34	and	and	CCONJ	CC	_	36	cc
#
# 35	Land	land	PROPN	NNP	Number=Sing	36	compound
#
# 36	Rovers	Rovers	PROPN	NNPS	Number=Plur	29	conj
#
# 37	(	(	PUNCT	-LRB-	_	39	punct
#
# 38	5	5	NUM	CD	NumType=Card	39	nummod
#
# 39	%	%	SYM	NN	Number=Sing	36	appos
#
# 40	)	)	PUNCT	-RRB-	_	39	punct
#
# 41	.	.	PUNCT	.	_	43	punct
#
# 42	Winners	winner	NOUN	NNS	Number=Plur	43	nsubj
#
# 43	spent	spend	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	5	parataxis
#
# 44	463	463	NUM	CD	NumType=Card	45	compound
#
# 45	m	m	NUM	CD	NumType=Card	43	obj
#
# 46	on	on	ADP	IN	_	48	case
#
# 47	17,190	17,190	NUM	CD	NumType=Card	48	nummod
#
# 48	cars	car	NOUN	NNS	Number=Plur	43	obl
#
# 49	,	,	PUNCT	,	_	43	punct
#
# 50	with	with	ADP	IN	_	53	case
#
# 51	the	the	DET	DT	Definite=Def|PronType=Art	53	det
#
# 52	average	average	ADJ	JJ	Degree=Pos	53	amod
#
# 53	price	price	NOUN	NN	Number=Sing	58	nsubj
#
# 54	of	of	ADP	IN	_	56	case
#
# 55	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	56	nmod:poss
#
# 56	favourite	favourite	NOUN	NN	Number=Sing	53	nmod
#
# 57	being	be	AUX	VBG	VerbForm=Ger	58	cop
#
# 58	46,116	46,116	NUM	CD	NumType=Card	43	advcl
#
# 59	.	.	PUNCT	.	_	5	punct
#
# 1	Holidays	Holidays	NOUN	NNS	Number=Plur	5	nsubj
#
# 2	were	be	AUX	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	5	cop
#
# 3	also	also	ADV	RB	_	5	advmod
#
# 4	a	a	DET	DT	Definite=Ind|PronType=Art	5	det
#
# 5	priority	priority	NOUN	NN	Number=Sing	0	root
#
# 6	.	.	PUNCT	.	_	5	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det
#
# 2	majority	majority	NOUN	NN	Number=Sing	7	nsubj
#
# 3	(	(	PUNCT	-LRB-	_	5	punct
#
# 4	68	68	NUM	CD	NumType=Card	5	nummod
#
# 5	%	%	SYM	NN	Number=Sing	2	appos
#
# 6	)	)	PUNCT	-RRB-	_	5	punct
#
# 7	choose	choose	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	0	root
#
# 8	five	five	NUM	CD	NumType=Card	10	nummod
#
# 9	-	-	PUNCT	HYPH	_	10	punct
#
# 10	star	star	NOUN	NN	Number=Sing	11	compound
#
# 11	hotels	hotel	NOUN	NNS	Number=Plur	7	obj
#
# 12	overseas	overseas	ADV	RB	_	7	advmod
#
# 13	.	.	PUNCT	.	_	7	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det
#
# 2	US	US	PROPN	NNP	Number=Sing	6	nsubj
#
# 3	was	be	AUX	VBD	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	6	cop
#
# 4	the	the	DET	DT	Definite=Def|PronType=Art	6	det
#
# 5	favoured	favour	VERB	VBN	Tense=Past|VerbForm=Part	6	amod
#
# 6	destination	destination	NOUN	NN	Number=Sing	0	root
#
# 7	for	for	ADP	IN	_	9	case
#
# 8	27	27	NUM	CD	NumType=Card	9	nummod
#
# 9	%	%	SYM	NN	Number=Sing	6	nmod
#
# 10	,	,	PUNCT	,	_	6	punct
#
# 11	followed	follow	VERB	VBN	Tense=Past|VerbForm=Part	9	acl
#
# 12	by	by	ADP	IN	_	14	case
#
# 13	the	the	DET	DT	Definite=Def|PronType=Art	14	det
#
# 14	Caribbean	Caribbean	PROPN	NNP	Number=Sing	11	obl
#
# 15	(	(	PUNCT	-LRB-	_	17	punct
#
# 16	9	9	NUM	CD	NumType=Card	17	nummod
#
# 17	%	%	SYM	NN	Number=Sing	14	appos
#
# 18	)	)	PUNCT	-RRB-	_	17	punct
#
# 19	.	.	PUNCT	.	_	17	punct
#
# 20	Closer	Closer	ADJ	JJR	Degree=Cmp	6	parataxis
#
# 21	to	to	ADP	IN	_	22	case
#
# 22	home	home	NOUN	NN	Number=Sing	20	obl
#
# 23	,	,	PUNCT	,	_	20	punct
#
# 24	however	however	ADV	RB	_	30	advmod
#
# 25	,	,	PUNCT	,	_	30	punct
#
# 26	UK	UK	PROPN	NNP	Number=Sing	27	compound
#
# 27	caravan	caravan	PROPN	NNP	Number=Sing	28	compound
#
# 28	sales	sale	NOUN	NNS	Number=Plur	30	nsubj
#
# 29	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	30	aux
#
# 30	benefited	benefite	VERB	VBN	Tense=Past|VerbForm=Part	6	parataxis
#
# 31	.	.	PUNCT	.	_	30	punct
#
# 1	Over	over	ADP	IN	_	5	case
#
# 2	the	the	DET	DT	Definite=Def|PronType=Art	5	det
#
# 3	past	past	ADJ	JJ	Degree=Pos	5	amod
#
# 4	18	18	NUM	CD	NumType=Card	5	nummod
#
# 5	years	year	NOUN	NNS	Number=Plur	12	obl
#
# 6	,	,	PUNCT	,	_	12	punct
#
# 7	10	10	NUM	CD	NumType=Card	8	nummod
#
# 8	%	%	SYM	NN	Number=Sing	12	nsubj
#
# 9	of	of	ADP	IN	_	10	case
#
# 10	millionaires	millionaire	NOUN	NNS	Number=Plur	8	nmod
#
# 11	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	12	aux
#
# 12	bought	buy	VERB	VBN	Tense=Past|VerbForm=Part	0	root
#
# 13	a	a	DET	DT	Definite=Ind|PronType=Art	14	det
#
# 14	caravan	caravan	NOUN	NN	Number=Sing	12	obj
#
# 15	,	,	PUNCT	,	_	12	punct
#
# 16	generating	generate	VERB	VBG	VerbForm=Ger	12	advcl
#
# 17	sales	sale	NOUN	NNS	Number=Plur	16	obj
#
# 18	worth	worth	ADJ	JJ	Degree=Pos	16	xcomp
#
# 19	about	about	ADV	RB	_	20	advmod
#
# 20	7.4	7.4	NUM	CD	NumType=Card	21	compound
#
# 21	m	m	NUM	CD	NumType=Card	18	obj
#
# 22	.	.	PUNCT	.	_	12	punct
#
# 1	Some	some	DET	DT	_	2	det
#
# 2	winners	winner	NOUN	NNS	Number=Plur	8	nsubj
#
# 3	(	(	PUNCT	-LRB-	_	5	punct
#
# 4	15	15	NUM	CD	NumType=Card	5	nummod
#
# 5	%	%	SYM	NN	Number=Sing	2	appos
#
# 6	)	)	PUNCT	-RRB-	_	5	punct
#
# 7	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	8	aux
#
# 8	started	start	VERB	VBN	Tense=Past|VerbForm=Part	0	root
#
# 9	their	they	PRON	PRP$	Number=Plur|Person=3|Poss=Yes|PronType=Prs	11	nmod:poss
#
# 10	own	own	ADJ	JJ	Degree=Pos	11	amod
#
# 11	businesses	business	NOUN	NNS	Number=Plur	8	obj
#
# 12	,	,	PUNCT	,	_	8	punct
#
# 13	9	9	NUM	CD	NumType=Card	14	nummod
#
# 14	%	%	SYM	NN	Number=Sing	16	nsubj
#
# 15	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	16	aux
#
# 16	helped	help	VERB	VBN	Tense=Past|VerbForm=Part	8	parataxis
#
# 17	others	other	NOUN	NNS	Number=Plur	16	obj
#
# 18	to	to	PART	TO	_	19	mark
#
# 19	do	do	VERB	VB	VerbForm=Inf	16	xcomp
#
# 20	so	so	ADV	RB	_	19	advmod
#
# 21	,	,	PUNCT	,	_	26	punct
#
# 22	and	and	CCONJ	CC	_	26	cc
#
# 23	6	6	NUM	CD	NumType=Card	24	nummod
#
# 24	%	%	SYM	NN	Number=Sing	26	nsubj
#
# 25	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	26	aux
#
# 26	invested	invest	VERB	VBN	Tense=Past|VerbForm=Part	8	conj
#
# 27	in	in	ADP	IN	_	26	obl
#
# 28	or	or	CCONJ	CC	_	29	cc
#
# 29	bought	buy	VERB	VBN	Tense=Past|VerbForm=Part	26	conj
#
# 30	other	other	ADJ	JJ	Degree=Pos	32	amod
#
# 31	peoples	people	NOUN	NNS	Number=Plur	32	compound
#
# 32	businesses	business	NOUN	NNS	Number=Plur	26	obl
#
# 33	.	.	PUNCT	.	_	8	punct
#
# 1	Businesses	Business	NOUN	NNS	Number=Plur	2	nsubj
#
# 2	started	start	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root
#
# 3	or	or	CCONJ	CC	_	4	cc
#
# 4	supported	support	VERB	VBN	Tense=Past|VerbForm=Part	2	conj
#
# 5	by	by	ADP	IN	_	7	case
#
# 6	lottery	lottery	NOUN	NN	Number=Sing	7	compound
#
# 7	winners	winner	NOUN	NNS	Number=Plur	2	obl
#
# 8	employ	employ	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	2	conj
#
# 9	3,195	3,195	NUM	CD	NumType=Card	10	nummod
#
# 10	people	people	NOUN	NNS	Number=Plur	8	obj
#
# 11	,	,	PUNCT	,	_	8	punct
#
# 12	according	accord	VERB	VBG	VerbForm=Ger	15	case
#
# 13	to	to	ADP	IN	_	12	fixed
#
# 14	the	the	DET	DT	Definite=Def|PronType=Art	15	det
#
# 15	study	study	NOUN	NN	Number=Sing	8	obl
#
# 16	.	.	PUNCT	.	_	2	punct
# 1	Andy	Andy	PROPN	NNP	Number=Sing	9	nsubj
#
# 2	Logan	Logan	PROPN	NNP	Number=Sing	1	flat
#
# 3	,	,	PUNCT	,	_	1	punct
#
# 4	author	author	NOUN	NN	Number=Sing	1	appos
#
# 5	of	of	ADP	IN	_	7	case
#
# 6	the	the	DET	DT	Definite=Def|PronType=Art	7	det
#
# 7	report	report	NOUN	NN	Number=Sing	4	nmod
#
# 8	,	,	PUNCT	,	_	9	punct
#
# 9	said	say	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root
#
# 10	:	:	PUNCT	:	_	9	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det
#
# 2	effect	effect	NOUN	NN	Number=Sing	6	nsubj
#
# 3	of	of	ADP	IN	_	5	case
#
# 4	a	a	DET	DT	Definite=Ind|PronType=Art	5	det
#
# 5	win	win	NOUN	NN	Number=Sing	2	nmod
#
# 6	spreads	spread	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root
#
# 7	much	much	ADV	RB	_	8	advmod
#
# 8	further	further	ADV	RBR	Degree=Cmp	6	advmod
#
# 9	and	and	CCONJ	CC	_	10	cc
#
# 10	wider	wider	ADJ	JJR	Degree=Cmp	8	conj
#
# 11	than	than	SCONJ	IN	_	13	mark
#
# 12	we	we	PRON	PRP	Case=Nom|Number=Plur|Person=1|PronType=Prs	13	nsubj
#
# 13	anticipated	anticipate	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	10	advcl
#
# 14	.	.	PUNCT	.	_	6	punct
#
# 1	Not	not	PART	RB	_	2	advmod
#
# 2	only	only	ADV	RB	_	5	cc:preconj
#
# 3	does	do	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	aux
#
# 4	it	it	PRON	PRP	Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs	5	nsubj
#
# 5	transform	transform	VERB	VB	VerbForm=Inf	0	root
#
# 6	the	the	DET	DT	Definite=Def|PronType=Art	7	det
#
# 7	lives	life	NOUN	NNS	Number=Plur	5	obj
#
# 8	of	of	ADP	IN	_	9	case
#
# 9	friends	friend	NOUN	NNS	Number=Plur	7	nmod
#
# 10	and	and	CCONJ	CC	_	11	cc
#
# 11	family	family	NOUN	NN	Number=Sing	9	conj
#
# 12	,	,	PUNCT	,	_	16	punct
#
# 13	but	but	CCONJ	CC	_	16	cc
#
# 14	each	each	DET	DT	_	15	det
#
# 15	win	win	NOUN	NN	Number=Sing	16	nsubj
#
# 16	has	have	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	conj
#
# 17	a	a	DET	DT	Definite=Ind|PronType=Art	19	det
#
# 18	measurable	measurable	ADJ	JJ	Degree=Pos	19	amod
#
# 19	effect	effect	NOUN	NN	Number=Sing	16	obj
#
# 20	on	on	ADP	IN	_	23	case
#
# 21	the	the	DET	DT	Definite=Def|PronType=Art	23	det
#
# 22	UK	UK	PROPN	NNP	Number=Sing	23	compound
#
# 23	economy	economy	NOUN	NN	Number=Sing	19	nmod
#
# 24	,	,	PUNCT	,	_	16	punct
#
# 25	especially	especially	ADV	RB	_	32	advmod
#
# 26	with	with	ADP	IN	_	28	case
#
# 27	so	so	ADV	RB	_	28	advmod
#
# 28	much	much	ADJ	JJ	Degree=Pos	32	nsubj:pass
#
# 29	of	of	ADP	IN	_	30	case
#
# 30	it	it	PRON	PRP	Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs	28	nmod
#
# 31	being	be	AUX	VBG	VerbForm=Ger	32	aux:pass
#
# 32	spent	spend	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	16	advcl
#
# 33	in	in	ADP	IN	_	35	case
#
# 34	the	the	DET	DT	Definite=Def|PronType=Art	35	det
#
# 35	UK	UK	PROPN	NNP	Number=Sing	32	obl
#
# 36	.	.	PUNCT	.	_	5	punct
#
# 1	The	the	DET	DT	Definite=Def|PronType=Art	2	det
#
# 2	use	use	NOUN	NN	Number=Sing	6	nsubj
#
# 3	of	of	ADP	IN	_	5	case
#
# 4	each	each	DET	DT	_	5	det
#
# 5	win	win	NOUN	NN	Number=Sing	2	nmod
#
# 6	creates	create	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root
#
# 7	a	a	DET	DT	Definite=Ind|PronType=Art	9	det
#
# 8	ripple	ripple	NOUN	NN	Number=Sing	9	compound
#
# 9	effect	effect	NOUN	NN	Number=Sing	6	obj
#
# 10	across	across	ADP	IN	_	12	case
#
# 11	this	this	DET	DT	Number=Sing|PronType=Dem	12	det
#
# 12	generation	generation	NOUN	NN	Number=Sing	9	nmod
#
# 13	and	and	CCONJ	CC	_	17	cc
#
# 14	very	very	ADV	RB	_	15	advmod
#
# 15	often	often	ADV	RB	_	17	advmod
#
# 16	the	the	DET	DT	Definite=Def|PronType=Art	17	det
#
# 17	next	next	ADJ	JJ	Degree=Pos	6	conj
#
# 18	.	.	PUNCT	.	_	6	punct

# %%
import stanfordnlp

MODELS_DIR = '.'
stanfordnlp.download('en', MODELS_DIR) # Download the English models
nlp = stanfordnlp.Pipeline(processors='tokenize,pos', models_dir=MODELS_DIR, treebank='en_ewt', use_gpu=True, pos_batch_size=3000) # Build the pipeline, specify part-of-speech processor's batch size
doc = nlp("Barack Obama was born in Hawaii.") # Run the pipeline on input text
doc.sentences[0].print_tokens() # Look at the result
# Out:
# Using the default treebank "en_ewt" for language "en".
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': './en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': './en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': './en_ewt_models/en_ewt.pretrain.pt', 'batch_size': 3000, 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---
# <Token index=1;words=[<Word index=1;text=Barack;upos=PROPN;xpos=NNP;feats=Number=Sing>]>
# <Token index=2;words=[<Word index=2;text=Obama;upos=PROPN;xpos=NNP;feats=Number=Sing>]>
# <Token index=3;words=[<Word index=3;text=was;upos=AUX;xpos=VBD;feats=Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin>]>
# <Token index=4;words=[<Word index=4;text=born;upos=VERB;xpos=VBN;feats=Tense=Past|VerbForm=Part|Voice=Pass>]>
# <Token index=5;words=[<Word index=5;text=in;upos=ADP;xpos=IN;feats=_>]>
# <Token index=6;words=[<Word index=6;text=Hawaii;upos=PROPN;xpos=NNP;feats=Number=Sing>]>
# <Token index=7;words=[<Word index=7;text=.;upos=PUNCT;xpos=.;feats=_>]>
